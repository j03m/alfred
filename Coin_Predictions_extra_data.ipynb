# %% [markdown]
# <a href="https://colab.research.google.com/github/j03m/lstm-price-predictor/blob/main/Coin_Predictions_close.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TODO: You broke it. Go back and fix it, try to understand the lstm params.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import plotly.express as px
from copy import copy
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import plotly.figure_factory as ff
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, confusion_matrix, classification_report, accuracy_score, f1_score
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
import requests
from requests.exceptions import HTTPError
import json as js
from datetime import datetime, timedelta 
import time
from os.path import exists
from decimal import *
#pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
# Function to plot interactive plots using Plotly Express
sc = MinMaxScaler()

coin_base = False
ku_coin = True
COINBASE_REST_API = 'https://api.pro.coinbase.com' 
COINBASE_PRODUCTS = COINBASE_REST_API+'/products'
KUCOIN_REST_API = "https://api.kucoin.com"
KUCOIN_PRODUCTS = KUCOIN_REST_API+ "/api/v1/market/allTickers"
KUCOIN_CANDLES = KUCOIN_REST_API+ "/api/v1/market/candles"
trend_periods = [7, 15]
trend_labels = ["7Trend", "15Trend"]
feature_columns = ["Close", "Volume"] + trend_labels
num_features = len(feature_columns)

data_path = '/content/drive/My Drive/output.csv'
model_path = "/content/drive/My Drive/model_long_trends.h5"
old_model_path = "/content/drive/My Drive/model_ohlc.h5"

def interactive_plot(df, title):
  fig = px.line(title = title)
  for i in df.columns[1:]:
    fig.add_scatter(x = df['Date'], y = df[i], name = i)
  fig.show()

def get_single_stock(price_df, vol_df, name):
    return pd.DataFrame({'Date': price_df['Date'], 'Close': price_df[name], 'Volume': vol_df[name]})

def scale_data(data):
  # Scale the data
  scaled_data = sc.fit_transform(data)
  return scaled_data

def sort_date(pric_df):
  pric_df = pric_df.sort_values(by = ['Date'])
  return pric_df

def append_price_dif(df):
  df['Target'] = df['Close'].shift(-1)
  df['Diff'] = df['Target'] - df['Close']
  df = df[:-1]
  return df

def append_price_dif_(df):
  df['Target'] = df['Close'].shift(-1)
  df['Diff'] = df['Target'] - df['Close']
  return df

def append_trend_slope(df, durations):
  for duration in durations:
    df[str(duration) + 'Close'] = df['Close'].shift(duration)
    df[str(duration) + 'Date'] = df['Date'].shift(duration)
    df[str(duration) + 'Trend'] = (df['Close'] - df[str(duration) + 'Close']) / duration  
  df = df[15:]
  return df

def show_plot(data, title):
  plt.figure(figsize = (13, 5))
  plt.plot(data, linewidth = 3)
  plt.title(title)
  plt.grid()

def build_model(features, outcomes):
  # Create the model
  inputs = keras.layers.Input(shape=(features,outcomes))
  x = keras.layers.LSTM(150, return_sequences= True)(inputs)
  x = keras.layers.Dropout(0.3)(x)
  x = keras.layers.LSTM(150, return_sequences=True)(x)
  x = keras.layers.Dropout(0.3)(x)
  x = keras.layers.LSTM(150)(x)
  outputs = keras.layers.Dense(1, activation='linear')(x)

  model = keras.Model(inputs=inputs, outputs=outputs)
  model.compile(optimizer='adam', loss="mse")
  return model

def connect(url, params):   
  response = requests.get(url,params)
  response.raise_for_status()
  return response

def coinbase_json_to_df(delta, product, granularity='86400'):
  start_date = (datetime.today() - timedelta(seconds=delta*int(granularity))).isoformat()
  end_date = datetime.now().isoformat()
  # Please refer to the coinbase documentation on the expected parameters
  params = {'start':start_date, 'end':end_date, 'granularity':granularity}
  response = connect(COINBASE_PRODUCTS+'/' + product + '/candles', params)
  response_text = response.text
  df_history = pd.read_json(response_text)
  # Add column names in line with the Coinbase Pro documentation
  df_history.columns = ['time','low','high','open','close','volume']
  df_history['time'] = [datetime.fromtimestamp(x) for x in df_history['time']]
  return df_history

def ku_coin_json_to_df(delta, product, granularity='86400'):
  granularity = int(granularity)
  start_date = (datetime.today() - timedelta(seconds=delta*granularity))
  end_date = datetime.now()

  # Please refer to the kucoin documentation on the expected parameters
  params = {'startAt':int(start_date.timestamp()), 'endAt':int(end_date.timestamp()), 'type':gran_to_string(granularity), 'symbol':product}
  response = connect(KUCOIN_CANDLES, params)
  response_text = response.text
  response_data = js.loads(response_text);
  if (response_data["code"] != "200000"):
    raise Exception("Illegal response: " + response_text)
  
  df_history = pd.DataFrame(response_data["data"])

  # kucoin is weird in that they don't have candles for everything. IF we don't have the requested
  # number of bars here, it throws off the whole algo. I don't want to try and project so we 
  # just won't trade those instruments
  got_bars = len(df_history)
  if ( got_bars < delta):
    raise Exception("Requested:" + str(delta) + " bars " + " but only got:" + str(got_bars))

  df_history.columns = ['time','open','close','high','low','volume', 'amount']
  df_history['time'] = [datetime.fromtimestamp(int(x)) for x in df_history['time']]
  df_history['open'] = [float(x) for x in df_history['open']]
  df_history['close'] = [float(x) for x in df_history['close']]
  df_history['high'] = [float(x) for x in df_history['high']]
  df_history['low'] = [float(x) for x in df_history['low']]
  df_history['low'] = [float(x) for x in df_history['low']]
  df_history['volume'] = [float(x) for x in df_history['volume']]
  df_history['amount'] = [float(x) for x in df_history['amount']]
  return df_history
  
def gran_to_string(granularity):
  #todo implement this actually
  return "1day"

def get_coin_data_frames(time, product, granularity='86400'):
  if coin_base:
    df_raw = coinbase_json_to_df(time, product, granularity)
  else:
    df_raw = ku_coin_json_to_df(time, product, granularity)

  df_btc_history = df_raw
  if len(df_btc_history.index) == 0:
    print("No data for ", product)
  
  df_btc_history = df_btc_history.rename(columns={"time":"Date", "close":"Close", "volume":"Volume"})
  df_btc_history = sort_date(df_btc_history)
  df_btc_history = df_btc_history.drop(columns={"high", "low", "open"})
  df_btc_history = append_price_dif_(df_btc_history)
  df_btc_history = append_trend_slope(df_btc_history, trend_periods)
  df_btc_features = df_btc_history[feature_columns]
  df_history_scaled = sc.fit_transform(df_btc_features)
  
  return [df_btc_history, df_btc_features, df_history_scaled, df_raw]

def build_profit_estimate(predicted, df_btc_history):
  df_predicted_chart = pd.DataFrame();
  df_predicted_chart["Date"] = df_btc_history["Date"]
  df_predicted_chart["Predicted"] = predicted
  df_predicted_chart["Predicted-Target"] = df_predicted_chart["Predicted"].shift(-1)
  df_predicted_chart["Predicted-Diff"] = df_predicted_chart["Predicted-Target"] - df_predicted_chart["Predicted"]
  df_predicted_chart["Should-Trade"] = np.where(df_predicted_chart["Predicted-Diff"] > 0, True, False)
  df_predicted_chart["RealDiff"] = df_btc_history["Diff"]
  df_predicted_chart["Percent"] = df_predicted_chart["RealDiff"] / df_btc_history["Close"]
  df_predicted_chart["Profit"] = np.where(df_predicted_chart["Should-Trade"] > 0, df_predicted_chart["Percent"] * budget, 0)
  profit = df_predicted_chart["Profit"].sum()
  return [df_predicted_chart, profit]

def get_all_products():
  if coin_base:
    return get_all_coinbase_products()
  
  if ku_coin:
    return get_all_kucoin_products()

def get_all_kucoin_products():
  response = connect(KUCOIN_PRODUCTS, {})
  products = js.loads(response.text)
  df_products = pd.DataFrame(products["data"]["ticker"])
  df_products = df_products.rename(columns={"symbol":"id"})
  return df_products

def get_all_coinbase_products():
  response = connect(COINBASE_PRODUCTS, {})
  response_text = response.text
  df_products = pd.read_json(response_text)
  return df_products

def predict_trade(product, bars):
  [df_full, df_features, npa_scaled, df_raw] = get_coin_data_frames(bars, product)
  predicted = model.predict(npa_scaled).flatten()
  
  #convert to data frames that have the correct shape for being unscaled
  df_scaled = pd.DataFrame(npa_scaled, columns = ["Close", "Volume"])
  
  # I want to believe that scaling happens on a per column basis, we only care about
  # price here so we will dummy out volume and trend and use the scaler on it
  # this kinda sucks, if we add features we'll need to add them here for unscaling
  df_temp = pd.DataFrame(predicted, columns = ["Close"])
  df_temp = zero_irrelevant_columns(df_temp)
  
  # unscale them both
  df_temp = pd.DataFrame(sc.inverse_transform(df_temp), columns = ["Close", "Volume", "Trend"])
  df_trade = pd.DataFrame(sc.inverse_transform(df_scaled), columns = ["Close", "Volume", "Trend"])
  
  # add predicted
  df_trade["Predicted"] = df_temp["Close"]
  df_trade = df_trade.tail(1)

  # add the product, derive a move and percent
  df_trade["Product"] = product;
  df_trade["Move"] = df_trade["Predicted"] - df_trade["Close"]
  df_trade["Percent"] = (df_trade["Move"] / df_trade["Close"]) * 100
  df_trade["RawPercent"] = df_trade["Move"] / df_trade["Close"]
  df_trade["250Fees"] = (250 * 0.004) * 2
  df_trade["5kFees"] = (5000 * 0.004) * 2
  df_trade["10kFees"] = (10000 * 0.0025) * 2
  df_trade["250Profit"] = (250 * df_trade["RawPercent"]) - df_trade["250Fees"] 
  df_trade["5kProfit"] = (5000 * df_trade["RawPercent"]) - df_trade["5kFees"]
  df_trade["10k0Profit"] = (10000 * df_trade["RawPercent"]) - df_trade["10kFees"]
  return df_trade

def zero_irrelevant_columns(df):
  df["Volume"] = 0
  for label in trend_labels:
    df[label] = 0
  return df

def get_training_set_for(ticker):
  target_df = get_single_stock(all_stocks_price_df, all_stocks_vol_df, ticker)
  target_df = append_price_dif(target_df)
  target_df = append_trend_slope(target_df, trend_periods)
  features = target_df[trend_labels + ["Close", "Volume", "Target"]]
  scaled_features = scale_data(features)
  X = []
  y = []
  for i in range(0, len(target_df)):
    X.append(scaled_features [i][0:num_features])
    y.append(scaled_features [i][num_features])
  
  X = np.asarray(X)
  y = np.asarray(y)
  return [scaled_features, X, y]
  
def train_model(model, X, y):

  # One day we might need test, but for now we don't we can use another
  # time series, we have so many
  # Split the data
  #split = int(0.7 * len(X))
  #X_train = X[:split]
  #y_train = y[:split]
  #X_test = X[split:]
  #y_test = y[split:]

  # Reshape the 1D arrays to 3D arrays to feed in the model
  X_train = np.reshape(X, (X.shape[0], X.shape[1], 1))
  
  history = model.fit(
      X_train, y,
      epochs = 20,
      batch_size = 32,
      validation_split = 0.2
  )
  return [model, history]

#pull training data 
all_stocks_price_df = sort_date(pd.read_csv('/content/drive/My Drive/Colab Notebooks/stock.csv'))
all_stocks_vol_df = sort_date(pd.read_csv("/content/drive/My Drive/Colab Notebooks/stock_volume.csv"))

# %% [markdown]
# #Library

# %% [markdown]
# # Get or Train a Model

# %%
target_df = get_single_stock(all_stocks_price_df, all_stocks_vol_df, "sp500")
target_df = append_price_dif(target_df)
target_df = append_trend_slope(target_df, trend_periods)
features = target_df[trend_labels + ["Close", "Volume", "Target"]]
features
# Out:
#          7Trend   15Trend        Close      Volume       Target
# 15     2.691424  3.293335  1344.900024  4608550000  1344.329956
# 16     3.699986  3.682666  1344.329956  3379700000  1347.050049
# 17     4.388585  3.558667  1347.050049  3742460000  1349.959961
# 18     5.278564  2.794661  1349.959961  4096730000  1351.949951
# 19     5.648560  2.496663  1351.949951  4209890000  1342.640015
# ...         ...       ...          ...         ...          ...
# 2153  12.982875  7.265999  3306.510010  4621670000  3327.770020
# 2154  12.622873  6.747331  3327.770020  4732220000  3349.159912
# 2155  18.674282  8.905990  3349.159912  4267490000  3351.280029
# 2156  13.262870  8.436670  3351.280029  4104860000  3360.469971
# 2157  16.321429  7.241992  3360.469971  4318570000  3333.689941
#
# [2143 rows x 5 columns]

# %%
model = None
file_exists = exists(model_path)

if file_exists:
  print("hello")
  model = keras.models.load_model(model_path)
else:
  print("nope")
  [scaled_features, X, y] = get_training_set_for("sp500")  
  model = build_model(num_features, 1)
  [model, history] = train_model(model, X, y)
# Out:
# nope
# Epoch 1/20
# 54/54 [==============================] - 15s 122ms/step - loss: 0.0465 - val_loss: 0.1285
# Epoch 2/20
# 54/54 [==============================] - 3s 46ms/step - loss: 0.0295 - val_loss: 0.0799
# Epoch 3/20
# 54/54 [==============================] - 2s 38ms/step - loss: 0.0115 - val_loss: 0.0459
# Epoch 4/20
# 54/54 [==============================] - 2s 37ms/step - loss: 0.0065 - val_loss: 0.0242
# Epoch 5/20
# 54/54 [==============================] - 2s 37ms/step - loss: 0.0049 - val_loss: 0.0294
# Epoch 6/20
# 54/54 [==============================] - 2s 38ms/step - loss: 0.0041 - val_loss: 0.0214
# Epoch 7/20
# 54/54 [==============================] - 2s 38ms/step - loss: 0.0037 - val_loss: 0.0152
# Epoch 8/20
# 54/54 [==============================] - 2s 39ms/step - loss: 0.0034 - val_loss: 0.0163
# Epoch 9/20
# 54/54 [==============================] - 2s 39ms/step - loss: 0.0028 - val_loss: 0.0131
# Epoch 10/20
# 54/54 [==============================] - 2s 38ms/step - loss: 0.0028 - val_loss: 0.0131
# Epoch 11/20
# 54/54 [==============================] - 2s 38ms/step - loss: 0.0026 - val_loss: 0.0126
# Epoch 12/20
# 54/54 [==============================] - 2s 37ms/step - loss: 0.0028 - val_loss: 0.0094
# Epoch 13/20
# 54/54 [==============================] - 2s 38ms/step - loss: 0.0022 - val_loss: 0.0100
# Epoch 14/20
# 54/54 [==============================] - 2s 38ms/step - loss: 0.0022 - val_loss: 0.0084
# Epoch 15/20
# 54/54 [==============================] - 2s 37ms/step - loss: 0.0020 - val_loss: 0.0079
# Epoch 16/20
# 54/54 [==============================] - 2s 39ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 17/20
# 54/54 [==============================] - 2s 38ms/step - loss: 0.0016 - val_loss: 0.0064
# Epoch 18/20
# 54/54 [==============================] - 2s 38ms/step - loss: 0.0014 - val_loss: 0.0061
# Epoch 19/20
# 54/54 [==============================] - 2s 36ms/step - loss: 0.0016 - val_loss: 0.0060
# Epoch 20/20
# 54/54 [==============================] - 2s 37ms/step - loss: 0.0013 - val_loss: 0.0055

# %%
# additional training?
if 1:
  [scaled_features, X, y] = get_training_set_for("TSLA")  
  [model, history] = train_model(model, X, y)
# Out:
# Epoch 1/20
# 51/51 [==============================] - 3s 53ms/step - loss: 5.9667e-04 - val_loss: 0.0022
# Epoch 2/20
# 51/51 [==============================] - 3s 51ms/step - loss: 4.2934e-04 - val_loss: 0.0024
# Epoch 3/20
# 51/51 [==============================] - 3s 52ms/step - loss: 3.1582e-04 - val_loss: 0.0017
# Epoch 4/20
# 51/51 [==============================] - 3s 53ms/step - loss: 2.7947e-04 - val_loss: 0.0018
# Epoch 5/20
# 51/51 [==============================] - 3s 51ms/step - loss: 2.1316e-04 - val_loss: 0.0022
# Epoch 6/20
# 51/51 [==============================] - 3s 52ms/step - loss: 1.8914e-04 - val_loss: 0.0018
# Epoch 7/20
# 51/51 [==============================] - 3s 54ms/step - loss: 1.7657e-04 - val_loss: 0.0016
# Epoch 8/20
# 51/51 [==============================] - 3s 51ms/step - loss: 1.5610e-04 - val_loss: 0.0014
# Epoch 9/20
# 51/51 [==============================] - 3s 51ms/step - loss: 1.2128e-04 - val_loss: 0.0015
# Epoch 10/20
# 51/51 [==============================] - 3s 51ms/step - loss: 1.1600e-04 - val_loss: 0.0014
# Epoch 11/20
# 51/51 [==============================] - 3s 52ms/step - loss: 1.1507e-04 - val_loss: 0.0012
# Epoch 12/20
# 51/51 [==============================] - 3s 52ms/step - loss: 1.0782e-04 - val_loss: 0.0012
# Epoch 13/20
# 51/51 [==============================] - 3s 52ms/step - loss: 8.6753e-05 - val_loss: 0.0011
# Epoch 14/20
# 51/51 [==============================] - 3s 53ms/step - loss: 8.4635e-05 - val_loss: 0.0010
# Epoch 15/20
# 51/51 [==============================] - 3s 52ms/step - loss: 7.4209e-05 - val_loss: 9.3304e-04
# Epoch 16/20
# 51/51 [==============================] - 3s 54ms/step - loss: 6.5118e-05 - val_loss: 0.0012
# Epoch 17/20
# 51/51 [==============================] - 3s 52ms/step - loss: 6.7935e-05 - val_loss: 8.7864e-04
# Epoch 18/20
# 51/51 [==============================] - 3s 52ms/step - loss: 6.4169e-05 - val_loss: 0.0011
# Epoch 19/20
# 51/51 [==============================] - 3s 51ms/step - loss: 6.7366e-05 - val_loss: 0.0011
# Epoch 20/20
# 51/51 [==============================] - 3s 51ms/step - loss: 7.1981e-05 - val_loss: 9.2198e-04

# %% [markdown]
# # Visualize and Backtest

# %%
budget = 5000
[btc_history, df_btc_features, npa_scaled, df_raw] = get_coin_data_frames(180, "BTC-USDT")
predicted = model.predict(npa_scaled).flatten()[::-1] 
df_temp = pd.DataFrame(predicted, columns = ["Close"])
df_temp = zero_irrelevant_columns(df_temp)
df_temp = pd.DataFrame(sc.inverse_transform(df_temp), columns = feature_columns)
btc_history["Predicted"] = df_temp["Close"]
[df_profit, profit] = build_profit_estimate(predicted, btc_history)
interactive_plot(btc_history[["Date","Close", "Predicted"]], "Actual vs Predicted")
print("Profit:", profit)
# Out:
# 6/6 [==============================] - 2s 12ms/step
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cf1ff192-3f72-4e2e-bd83-5406927c67a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf1ff192-3f72-4e2e-bd83-5406927c67a5")) {                    Plotly.newPlot(                        "cf1ff192-3f72-4e2e-bd83-5406927c67a5",                        [{"name":"Close","x":["2022-07-16T00:00:00","2022-07-17T00:00:00","2022-07-18T00:00:00","2022-07-19T00:00:00","2022-07-20T00:00:00","2022-07-21T00:00:00","2022-07-22T00:00:00","2022-07-23T00:00:00","2022-07-24T00:00:00","2022-07-25T00:00:00","2022-07-26T00:00:00","2022-07-27T00:00:00","2022-07-28T00:00:00","2022-07-29T00:00:00","2022-07-30T00:00:00","2022-07-31T00:00:00","2022-08-01T00:00:00","2022-08-02T00:00:00","2022-08-03T00:00:00","2022-08-04T00:00:00","2022-08-05T00:00:00","2022-08-06T00:00:00","2022-08-07T00:00:00","2022-08-08T00:00:00","2022-08-09T00:00:00","2022-08-10T00:00:00","2022-08-11T00:00:00","2022-08-12T00:00:00","2022-08-13T00:00:00","2022-08-14T00:00:00","2022-08-15T00:00:00","2022-08-16T00:00:00","2022-08-17T00:00:00","2022-08-18T00:00:00","2022-08-19T00:00:00","2022-08-20T00:00:00","2022-08-21T00:00:00","2022-08-22T00:00:00","2022-08-23T00:00:00","2022-08-24T00:00:00","2022-08-25T00:00:00","2022-08-26T00:00:00","2022-08-27T00:00:00","2022-08-28T00:00:00","2022-08-29T00:00:00","2022-08-30T00:00:00","2022-08-31T00:00:00","2022-09-01T00:00:00","2022-09-02T00:00:00","2022-09-03T00:00:00","2022-09-04T00:00:00","2022-09-05T00:00:00","2022-09-06T00:00:00","2022-09-07T00:00:00","2022-09-08T00:00:00","2022-09-09T00:00:00","2022-09-10T00:00:00","2022-09-11T00:00:00","2022-09-12T00:00:00","2022-09-13T00:00:00","2022-09-14T00:00:00","2022-09-15T00:00:00","2022-09-16T00:00:00","2022-09-17T00:00:00","2022-09-18T00:00:00","2022-09-19T00:00:00","2022-09-20T00:00:00","2022-09-21T00:00:00","2022-09-22T00:00:00","2022-09-23T00:00:00","2022-09-24T00:00:00","2022-09-25T00:00:00","2022-09-26T00:00:00","2022-09-27T00:00:00","2022-09-28T00:00:00","2022-09-29T00:00:00","2022-09-30T00:00:00","2022-10-01T00:00:00","2022-10-02T00:00:00","2022-10-03T00:00:00","2022-10-04T00:00:00","2022-10-05T00:00:00","2022-10-06T00:00:00","2022-10-07T00:00:00","2022-10-08T00:00:00","2022-10-09T00:00:00","2022-10-10T00:00:00","2022-10-11T00:00:00","2022-10-12T00:00:00","2022-10-13T00:00:00","2022-10-14T00:00:00","2022-10-15T00:00:00","2022-10-16T00:00:00","2022-10-17T00:00:00","2022-10-18T00:00:00","2022-10-19T00:00:00","2022-10-20T00:00:00","2022-10-21T00:00:00","2022-10-22T00:00:00","2022-10-23T00:00:00","2022-10-24T00:00:00","2022-10-25T00:00:00","2022-10-26T00:00:00","2022-10-27T00:00:00","2022-10-28T00:00:00","2022-10-29T00:00:00","2022-10-30T00:00:00","2022-10-31T00:00:00","2022-11-01T00:00:00","2022-11-02T00:00:00","2022-11-03T00:00:00","2022-11-04T00:00:00","2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00","2022-11-10T00:00:00","2022-11-11T00:00:00","2022-11-12T00:00:00","2022-11-13T00:00:00","2022-11-14T00:00:00","2022-11-15T00:00:00","2022-11-16T00:00:00","2022-11-17T00:00:00","2022-11-18T00:00:00","2022-11-19T00:00:00","2022-11-20T00:00:00","2022-11-21T00:00:00","2022-11-22T00:00:00","2022-11-23T00:00:00","2022-11-24T00:00:00","2022-11-25T00:00:00","2022-11-26T00:00:00","2022-11-27T00:00:00","2022-11-28T00:00:00","2022-11-29T00:00:00","2022-11-30T00:00:00","2022-12-01T00:00:00","2022-12-02T00:00:00","2022-12-03T00:00:00","2022-12-04T00:00:00","2022-12-05T00:00:00","2022-12-06T00:00:00","2022-12-07T00:00:00","2022-12-08T00:00:00","2022-12-09T00:00:00","2022-12-10T00:00:00","2022-12-11T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00", ...
# Profit: -860.3540479165064

# %% [markdown]
# # Which coins are most profitable based on the above trading signals?

# %%
# download all known products and check who has the highest profit in 90 days
"""
# Fetch the top 10 and see if they predict up
df_products = get_all_products()
df_products = df_products[df_products.id.str.endswith('USD')]
df_products = df_products[df_products.trading_disabled == False]
df_products = df_products[df_products.cancel_only == False]
df_profit = pd.DataFrame();
df_profit["Product"] = [];
df_profit["Profit"] = [];
for index, row in df_products.iterrows():
  try:
    print("fetching: ", row.id)
    [df_full, df_features, df_scaled] = get_coin_data_frames_test(90, row.id)
    predicted = model.predict(df_scaled.flatten())
    [df_chart, profit] = build_profit_estimate(predicted, df_full)
    df_profit.loc[len(df_profit.index)] = [row.id, profit] 
  except Exception as inst:
    print("Error: ", inst)
  time.sleep(1)

df_profit
"""
# Out:
# '\n# Fetch the top 10 and see if they predict up\ndf_products = get_all_products()\ndf_products = df_products[df_products.id.str.endswith(\'USD\')]\ndf_products = df_products[df_products.trading_disabled == False]\ndf_products = df_products[df_products.cancel_only == False]\ndf_profit = pd.DataFrame();\ndf_profit["Product"] = [];\ndf_profit["Profit"] = [];\nfor index, row in df_products.iterrows():\n  try:\n    print("fetching: ", row.id)\n    [df_full, df_features, df_scaled] = get_coin_data_frames_test(90, row.id)\n    predicted = model.predict(df_scaled.flatten())\n    [df_chart, profit] = build_profit_estimate(predicted, df_full)\n    df_profit.loc[len(df_profit.index)] = [row.id, profit] \n  except Exception as inst:\n    print("Error: ", inst)\n  time.sleep(1)\n\ndf_profit\n'

# %% [markdown]
# # What has a buy indicator for tomorrow?

# %%
predict_trade("DOGE3L-USDT", 90)
# Out:
# 3/3 [==============================] - 0s 15ms/step
#        Close        Volume     Trend  Predicted      Product      Move  \
# 74  0.000472  2.254780e+08 -0.000036   0.000526  DOGE3L-USDT  0.000054
#
#       Percent  RawPercent  250Fees  5kFees  10kFees  250Profit    5kProfit  \
# 74  11.380349    0.113803      2.0    40.0     50.0  26.450872  529.017438
#
#      10k0Profit
# 74  1088.034876

# %%
predict_trade("FCON-USDT", 90)
# Out:
# 3/3 [==============================] - 0s 9ms/step
#        Close        Volume     Trend  Predicted    Product      Move  \
# 74  0.000045  1.721042e+09 -0.000009   0.000051  FCON-USDT  0.000006
#
#       Percent  RawPercent  250Fees  5kFees  10kFees  250Profit    5kProfit  \
# 74  12.705889    0.127059      2.0    40.0     50.0  29.764723  595.294454
#
#      10k0Profit
# 74  1220.588907

# %%
# Fetch the top 10 and see if they predict up
df_products = get_all_products()
df_products = df_products[df_products.id.str.endswith('USDT')]

if coin_base:
  df_products = df_products[df_products.trading_disabled == False]
  df_products = df_products[df_products.cancel_only == False]

df_trades = pd.DataFrame();
bars = 90
counter = 0;
for index, row in df_products.iterrows():
  try:
    print("fetching: ", row.id)
    
    df_trade = predict_trade(row.id, bars)
   
    # we need to unscale the predicted values so that we have an entry and exit point
    # entry should be roughly close and exit should be roughly predicted

    # Stick this on the end of the main dataframe
    df_trades = df_trades.append(df_trade);
    
    #counter+=1
    #if counter > 5:
    #  break
  except Exception as inst:
    #raise inst
    print("Error: ", inst)
  time.sleep(0.5)
df_trades.reset_index()
df_buys = df_trades[df_trades['Move'] > 0] 
df_shorts = df_trades[df_trades['Move'] < 0]
# Out:
# fetching:  NKN-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  GEM-USDT
# Error:  Requested:90 bars  but only got:78
# fetching:  CUSD-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  LTC3L-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  OAS-USDT
# Error:  Requested:90 bars  but only got:16
# fetching:  KNC-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  LYM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HAI-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  MITX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PDEX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  FLAME-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  EPX-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  AOG-USDT
# Error:  Requested:90 bars  but only got:89
# fetching:  ATOM3L-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  AGLD-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  YLD-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  POWR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CWS-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  SENSO-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  ALBT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ALICE-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  UNIC-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  IHC-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  BULL-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  SWASH-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  XEC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ATOM3S-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  LINA-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  ETC-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  RUNE-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  MPLX-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  HYDRA-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ASTR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  BCH-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  NGM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  JAR-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  TONE-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  POSI-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  EOS3L-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  KAVA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GLQ-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  VSYS-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  GAS-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399864&endAt=1672175864&type=1day&symbol=GAS-USDT
# fetching:  APT-USDT
# Error:  Requested:90 bars  but only got:70
# fetching:  TRX-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  CELO-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  MOOV-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  SAND-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  FIDA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  KLAY-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399870&endAt=1672175870&type=1day&symbol=KLAY-USDT
# fetching:  T-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SUN-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  DATA-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  LABS-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  BOND-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  LTC3S-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  DPET-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  TARA-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  DERO-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  EFX-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  LDO-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  WOM-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399879&endAt=1672175879&type=1day&symbol=WOM-USDT
# fetching:  NUM-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  NMR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  TON-USDT
# Error:  Requested:90 bars  but only got:62
# fetching:  CWAR-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  AAVE-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  HIOD-USDT
# Error:  Requested:90 bars  but only got:71
# fetching:  AAVE3S-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399885&endAt=1672175885&type=1day&symbol=AAVE3S-USDT
# fetching:  HIGAZERS-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399885&endAt=1672175885&type=1day&symbol=HIGAZERS-USDT
# fetching:  CREDI-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LON-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  BTC3L-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  TRB-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ELA-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399890&endAt=1672175890&type=1day&symbol=ELA-USDT
# fetching:  DOGE-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ZEE-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  BICO-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  PRE-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  ENS-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  CTI-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  LPT-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  PMON-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  XNL-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  SPELL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  EOS3S-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  SYNR-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  TLOS-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  NAVI-USDT
# Error:  Requested:90 bars  but only got:29
# fetching:  WHALE-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  FCD-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  USDD-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MONI-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  ETH3S-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  NEO-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  BTC3S-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  BNT-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  CHZ-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  USDC-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  DOT-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  PSL-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  AZERO-USDT
# Error:  Requested:90 bars  but only got:43
# fetching:  RFOX-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  WXT-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  APL-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399914&endAt=1672175914&type=1day&symbol=APL-USDT
# fetching:  UNI3L-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399915&endAt=1672175915&type=1day&symbol=UNI3L-USDT
# fetching:  GAFI-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  EOS-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  UOS-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MNST-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  GMX-USDT
# Error:  Requested:90 bars  but only got:75
# fetching:  XCN-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  GHX-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  FTG-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  POLS-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  HISAND33-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  IOST-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  TVK-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399925&endAt=1672175925&type=1day&symbol=TVK-USDT
# fetching:  AMB-USDT
# Error:  Requested:90 bars  but only got:49
# fetching:  CCD-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ETH3L-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  OUSD-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  GMEE-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  DOT3S-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  HTR-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399930&endAt=1672175930&type=1day&symbol=HTR-USDT
# fetching:  CFG-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  UBX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ERTHA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  FEAR-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  NGL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BTC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AAVE3L-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PLU-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SUSHI3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  OCEAN-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GMB-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CGG-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399940&endAt=1672175940&type=1day&symbol=CGG-USDT
# fetching:  INDI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SRK-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  RED-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  APE-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ERG-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ZBC-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  SDL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  REVV-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GST-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  LOOKS-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  PROM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ARKER-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  HT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HAPI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  P00LS-USDT
# Error:  Requested:90 bars  but only got:78
# fetching:  ADA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  DIA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HNT-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ALPHA-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399955&endAt=1672175955&type=1day&symbol=ALPHA-USDT
# fetching:  DPR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HIODBS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AERGO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CFX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DOT3L-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  SRM-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  BOLT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ERN-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  XSR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  KMD-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  RBP-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HORD-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  EOSC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SUSHI3L-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  BUY-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CQT-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ISP-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  KRL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MAKI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ARX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CLV-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MAP-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ROSN-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  BTT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PUSH-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ZEC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  URUS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SYLO-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XTAG-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SPA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ICX-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  AGIX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SOLVE-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  VIDT-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  JASMY-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  KARA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  WIN-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SXP-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  VID-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FORESTPLUS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  TEL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ARRR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MEM-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399990&endAt=1672175990&type=1day&symbol=MEM-USDT
# fetching:  JASMY3S-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  HEART-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AXS3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CLUB-USDT
# Error:  Requested:90 bars  but only got:28
# fetching:  FCON-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  NYM-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664399995&endAt=1672175995&type=1day&symbol=NYM-USDT
# fetching:  GMT3S-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ORAI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  STC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  EPK-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HIFIDENZA-USDT
# Error:  Requested:90 bars  but only got:43
# fetching:  LTO-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  MJT-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400000&endAt=1672176000&type=1day&symbol=MJT-USDT
# fetching:  APE3L-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ACOIN-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400001&endAt=1672176001&type=1day&symbol=ACOIN-USDT
# fetching:  IDEA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  REN-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ANC-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  LUNC-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400005&endAt=1672176005&type=1day&symbol=LUNC-USDT
# fetching:  XRP3S-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  CARD-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  PLATO-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  SHILL-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400008&endAt=1672176008&type=1day&symbol=SHILL-USDT
# fetching:  SOUL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  DAG-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  XHV-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400010&endAt=1672176010&type=1day&symbol=XHV-USDT
# fetching:  SAND3S-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  STG-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  XMR-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  TOKO-USDT
# 3/3 [==============================] - 0s 24ms/step
# fetching:  EVER-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400014&endAt=1672176014&type=1day&symbol=EVER-USDT
# fetching:  POLC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ZEN-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ACT-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  VAI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FTM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ZCX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AXS3L-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  AKRO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XWG-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CKB-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  H2O-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  COV-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MTL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  NEAR3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MNET-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  SKEY-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  DYDX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XCV-USDT
# Error:  Requested:90 bars  but only got:55
# fetching:  1EARTH-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SOL3S-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  AUSD-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  XRP3L-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  OVR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  REQ-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SUKU-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400035&endAt=1672176035&type=1day&symbol=SUKU-USDT
# fetching:  DAO-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  WEST-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CIX100-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  BOSON-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AMP-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  BEAT-USDT
# Error:  Requested:90 bars  but only got:42
# fetching:  GODS-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  XPR-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  LOKI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  NEAR3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  EPS-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  JAM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ORBS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  FXS-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  RLC-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  UNFI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CIRUS-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FTT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FITFI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  HAKA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  YFDAI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MATIC3L-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FKX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SAND3L-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  KAR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  BASIC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XED-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  BCHSV-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SOL3L-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  SNX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PUMLX-USDT
# Error:  Requested:90 bars  but only got:82
# fetching:  AIOZ-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PBX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  INJ-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  TIDAL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  USDP-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  LPOOL-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  NHCT-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ATOM-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  MANA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PIAS-USDT
# Error:  Requested:90 bars  but only got:58
# fetching:  BRWL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ACQ-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ALT-USDT
# Error:  Requested:90 bars  but only got:27
# fetching:  FTM3L-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  AUDIO-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  VEGA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SHFT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  KSM-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ETH-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400075&endAt=1672176075&type=1day&symbol=ETH-USDT
# fetching:  STORJ-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400075&endAt=1672176075&type=1day&symbol=STORJ-USDT
# fetching:  OPCT-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400076&endAt=1672176076&type=1day&symbol=OPCT-USDT
# fetching:  HIDOODLES-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HIENS4-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  EFI-USDT
# Error:  Requested:90 bars  but only got:70
# fetching:  GALAX-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  BLOK-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  BURGER-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400081&endAt=1672176081&type=1day&symbol=BURGER-USDT
# fetching:  PEOPLE-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CWEB-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  BAL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SKU-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BUX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FLOW-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  GALAX3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  WMT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SUPER-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  IMX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  OLE-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400090&endAt=1672176090&type=1day&symbol=OLE-USDT
# fetching:  CREAM-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ADA3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  LINK3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MATIC3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PHNX-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  GARI-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  PNT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ROAR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  DSLA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SLCL-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  VRA-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  WAX-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  DEXE-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SHR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  LINK3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GMT3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  JASMY3L-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  CEEK-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XCH-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SDAO-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  SCLP-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HIMAYC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AI-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FORT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CMP-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FRM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  LMR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HISQUIGGLE-USDT
# Error:  Requested:90 bars  but only got:55
# fetching:  NTVRK-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AURY-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HAWK-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AKT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  TXA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CPOOL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  1INCH-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ALEPH-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PERP-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ADA3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MNW-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ANT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PRMX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HICOOLCATS-USDT
# Error:  Requested:90 bars  but only got:13
# fetching:  MTS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ABBC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ADX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MFT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CAKE-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XETA-USDT
# Error:  Requested:90 bars  but only got:79
# fetching:  NWC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DAR-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400135&endAt=1672176135&type=1day&symbol=DAR-USDT
# fetching:  AURORA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  GAL-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ONE-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SFUND-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  FTM3S-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SON-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  STEPWATCH-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AVAX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MASK-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  PIX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  FORM-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  MV-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400144&endAt=1672176144&type=1day&symbol=MV-USDT
# fetching:  GLMR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  VR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  POKT-USDT
# Error:  Requested:90 bars  but only got:70
# fetching:  DOGE3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  STX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XPRT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  OOE-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400150&endAt=1672176150&type=1day&symbol=OOE-USDT
# fetching:  SHA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  GLCH-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  GEEQ-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MBL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  H3RO3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MODEFI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  QRDO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XAVA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XYM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  LUNA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XNO-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  COOHA-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400160&endAt=1672176160&type=1day&symbol=COOHA-USDT
# fetching:  MLS-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MHC-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  MANA3S-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  DOGE3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CVX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  KYL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  EQZ-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  IOTA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XDEFI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DFI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HFT-USDT
# Error:  Requested:90 bars  but only got:51
# fetching:  CSPR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PUNDIX-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400170&endAt=1672176170&type=1day&symbol=PUNDIX-USDT
# fetching:  ELON-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  IXS-USDT
# 3/3 [==============================] - 0s 19ms/step
# fetching:  AXS-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  BNX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  VELO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CBC-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  KMA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  TITAN-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SRBP-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  OPUL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  VET3L-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FRONT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CAS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CELR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  KONO-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MTV-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CRO-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HARD-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  WOMBAT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MAN-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  SOL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  API3-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ECOX-USDT
# Error:  Requested:90 bars  but only got:51
# fetching:  YFI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SWFTC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MARSH-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  VET3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SYS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  KOL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  PLY-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MATIC-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400195&endAt=1672176195&type=1day&symbol=MATIC-USDT
# fetching:  SWEAT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  LTX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MTRG-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PAXG-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SIN-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XRP-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HIMEEBITS-USDT
# Error:  Requested:90 bars  but only got:57
# fetching:  BNB-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  PCX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  PRQ-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ALPINE-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CARE-USDT
# Error:  Requested:90 bars  but only got:28
# fetching:  NIM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  DYP-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  BOA-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  MAHA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  GALAX3L-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CRV-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  LOC-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  NOIA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  EGLD-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LSS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DFA-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  HIENS3-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  DINO-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400215&endAt=1672176215&type=1day&symbol=DINO-USDT
# fetching:  VLX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  PBR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MANA3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ERSDL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SWP-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  GENS-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  SHX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  GRT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  PHA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  UNB-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SKL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  DFYN-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  IDEX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  RMRK-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  BRISE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  OGV-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  WNCG-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FSN-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LOKA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  TRADE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  RACEFI-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  KAT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AVA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  COTI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GGG-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  WSIENNA-USDT
# 3/3 [==============================] - 0s 19ms/step
# fetching:  WOO-USDT
# 3/3 [==============================] - 0s 27ms/step
# fetching:  RACA-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  EUL-USDT
# Error:  Requested:90 bars  but only got:63
# fetching:  BUSD-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  REV3L-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  XCAD-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ACH-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  VET-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ILV-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  LBP-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400245&endAt=1672176245&type=1day&symbol=LBP-USDT
# fetching:  ODDZ-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  BNB3S-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  CHMB-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HICLONEX-USDT
# Error:  Requested:90 bars  but only got:20
# fetching:  TFUEL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  METIS-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  DUSK-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  TRU-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ZKT-USDT
# Error:  Requested:90 bars  but only got:0
# fetching:  BNC-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  POLX-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  PKF-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  LYXE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SHIB-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ILA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AVAX3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HIAZUKI-USDT
# Error:  Requested:90 bars  but only got:6
# fetching:  ONSTON-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XDB-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  UNI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  FT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ACA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MBOX-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  SWINGBY-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  REP-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  LOVE-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  WOOP-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  STRONG-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ARPA-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400275&endAt=1672176275&type=1day&symbol=ARPA-USDT
# fetching:  SDN-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FALCONS-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  THETA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HBAR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ETN-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  STARLY-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  KDON-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  NFTB-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GTC-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  XTM-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  SUSHI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  LTC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CELT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CULT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SCRT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TIME-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TLM-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  XCUR-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  VEED-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  LINK-USDT
# 3/3 [==============================] - 0s 21ms/step
# fetching:  AFK-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  PLD-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  WEMIX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  NDAU-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  APE3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  KDA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  KICKS-USDT
# Error:  Requested:90 bars  but only got:71
# fetching:  ROSE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ARNM-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  PEEL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TKY-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  XTZ-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MIR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  EXRD-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  UFO-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ACE-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400304&endAt=1672176304&type=1day&symbol=ACE-USDT
# fetching:  TRVL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  NEER-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HBB-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  DC-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400308&endAt=1672176308&type=1day&symbol=DC-USDT
# fetching:  RVN-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BCH3L-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  OP-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400310&endAt=1672176310&type=1day&symbol=OP-USDT
# fetching:  VXV-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400311&endAt=1672176311&type=1day&symbol=VXV-USDT
# fetching:  SOLR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  IOI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  DAPPT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ETHW-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  POND-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400315&endAt=1672176315&type=1day&symbol=POND-USDT
# fetching:  ICP-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LACE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BNS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  NORD-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  DG-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BNB3L-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  BAX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  LOCG-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  QI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XYO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AVAX3L-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  DGB-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LRC-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  EDG-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GRIN-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  REEF-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ANKR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  PEL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  CLH-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  DAPPX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FLY-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ROUTE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BAKE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BOBA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ORN-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400335&endAt=1672176335&type=1day&symbol=ORN-USDT
# fetching:  HIPUNKS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SLIM-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  POLK-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  WRX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CTSI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  MSWAP-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  EGAME-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FIL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BCH3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  C98-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  NGC-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  RSR-USDT
# 3/3 [==============================] - 0s 21ms/step
# fetching:  UNI3S-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  OOKI-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  GOVI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  RBS-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  PRIMAL-USDT
# Error:  Requested:90 bars  but only got:20
# fetching:  WILD-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400349&endAt=1672176349&type=1day&symbol=WILD-USDT
# fetching:  CUDOS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  NAKA-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  MXC-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  NFT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ONT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DERC-USDT
# Error:  Requested:90 bars  but only got:77
# fetching:  UMA-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400355&endAt=1672176355&type=1day&symbol=UMA-USDT
# fetching:  FORTH-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MOVR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  R-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DVPN-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  REVU-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  AR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  USTC-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  WELL-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  CTC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BEPRO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DREAMS-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  BAND-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  VOXEL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ATA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XLM-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  NRFB-USDT
# Error:  Requested:90 bars  but only got:35
# fetching:  YGG-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  BONDLY-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400370&endAt=1672176370&type=1day&symbol=BONDLY-USDT
# fetching:  POL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  KOK-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  LAVAX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  EQX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  DEGO-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  MLN-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  USDJ-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  BAT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  STND-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SFP-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  STMX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  BMON-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400384&endAt=1672176384&type=1day&symbol=BMON-USDT
# fetching:  SOS-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400385&endAt=1672176385&type=1day&symbol=SOS-USDT
# fetching:  UNO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ENQ-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SLP-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  MARS4-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XEM-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  KAI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  IOTX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  OXT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PSTAKE-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  OM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  GMM-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  RFUEL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ASD-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  KCS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  LIT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BSW-USDT
# 3/3 [==============================] - 0s 9ms/step
# fetching:  GMT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  TOWER-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  EWT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ADS-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  BIFI-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  SUTER-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  OMG-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  COCOS-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FRA-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ZIL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MATTER-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  TT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XDC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  COMP-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  BBC-USDT
# Error:  Requested:90 bars  but only got:63
# fetching:  HOTCROSS-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PYR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ALGO-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AMPL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  WAVES-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  PLGR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MELOS-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  RANKER-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  DASH-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  EPIK-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CRPT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HEGIC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  LIKE-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  VISION-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HERO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HIBAYC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SRBS-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  ENJ-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400425&endAt=1672176425&type=1day&symbol=ENJ-USDT
# fetching:  DODO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GLM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  TRIAS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DIVI-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TRIBL-USDT
# Error:  Requested:90 bars  but only got:76
# fetching:  WAL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HYVE-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  QUARTZ-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  QUICK-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GOM2-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  JST-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  RLY-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400434&endAt=1672176434&type=1day&symbol=RLY-USDT
# fetching:  ORC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FCL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  AOA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  TAUM-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MC-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  OGN-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  QNT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  NEAR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HIPENGUINS-USDT
# Error:  Requested:90 bars  but only got:27
# fetching:  BFC-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  REAP-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CHR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  KLV-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  TWT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LAYER-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MKR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  STORE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  LITH-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ALPACA-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664400450&endAt=1672176450&type=1day&symbol=ALPACA-USDT
# fetching:  FLUX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CERE-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SURV-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  KP3R-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  UPO-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  2CRZ-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  RNDR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FRR-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  DMTR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  TRIBE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MLK-USDT
# 3/3 [==============================] - 0s 18ms/step

# %%
df_shorts
# Out:
#        Close        Volume     Trend  Predicted     Product      Move  \
# 74  0.083305  8.374552e+04  0.000194   0.082526    NKN-USDT -0.000779
# 74  0.996800  2.301907e+04  0.000033   0.994825   CUSD-USDT -0.001975
# 74  0.001392  2.880934e+07 -0.000045   0.001387  LTC3L-USDT -0.000005
# 74  0.522000  1.845736e+04 -0.006867   0.520911    KNC-USDT -0.001089
# 74  0.001193  1.712094e+06 -0.000002   0.001171    LYM-USDT -0.000022
# ..       ...           ...       ...        ...         ...       ...
# 74  0.022930  8.060674e+05 -0.000053   0.022927  STORE-USDT -0.000003
# 74  0.459900  4.895358e+05 -0.002260   0.454928   FLUX-USDT -0.004972
# 74  0.006078  1.368320e+06  0.000113   0.006005   CERE-USDT -0.000073
# 74  0.000990  4.626607e+07 -0.000019   0.000978    FRR-USDT -0.000012
# 74  0.205900  3.981684e+04 -0.000447   0.205288  TRIBE-USDT -0.000612
#
#      Percent  RawPercent  250Fees  5kFees  10kFees  250Profit    5kProfit  \
# 74 -0.935604   -0.009356      2.0    40.0     50.0  -4.339010  -86.780207
# 74 -0.198125   -0.001981      2.0    40.0     50.0  -2.495314  -49.906273
# 74 -0.374473   -0.003745      2.0    40.0     50.0  -2.936183  -58.723663
# 74 -0.208630   -0.002086      2.0    40.0     50.0  -2.521575  -50.431507
# 74 -1.843701   -0.018437      2.0    40.0     50.0  -6.609253 -132.185056
# ..       ...         ...      ...     ...      ...        ...         ...
# 74 -0.012214   -0.000122      2.0    40.0     50.0  -2.030535  -40.610691
# 74 -1.081017   -0.010810      2.0    40.0     50.0  -4.702541  -94.050828
# 74 -1.196449   -0.011964      2.0    40.0     50.0  -4.991123  -99.822458
# 74 -1.236238   -0.012362      2.0    40.0     50.0  -5.090594 -101.811876
# 74 -0.297237   -0.002972      2.0    40.0     50.0  -2.743092  -54.861840
#
#     10k0Profit
# 74 -143.560414
# 74  -69.812545
# 74  -87.447326
# 74  -70.863014
# 74 -234.370113
# ..         ...
# 74  -51.221383
# 74 -158.101657
# 74 -169.644917
# 74 -173.623751
# 74  -79.723680
#
# [435 rows x 14 columns]

# %%
df_buys
# Out:
#        Close        Volume     Trend  Predicted     Product          Move  \
# 74  0.002934  2.681275e+07 -0.000053   0.002970   MITX-USDT  3.633959e-05
# 74  0.020300  7.692874e+06 -0.000172   0.020569  FLAME-USDT  2.686402e-04
# 74  0.073500  3.679475e+04 -0.000376   0.073751    YLD-USDT  2.508677e-04
# 74  0.222000  1.480038e+05 -0.005600   0.224207    CWS-USDT  2.206556e-03
# 74  1.071000  9.703112e+03 -0.012800   1.073180  ALICE-USDT  2.180058e-03
# ..       ...           ...       ...        ...         ...           ...
# 74  0.005050  5.860800e+07 -0.000050   0.005051    UPO-USDT  6.487185e-07
# 74  0.001581  3.837938e+07 -0.000035   0.001602   2CRZ-USDT  2.087899e-05
# 74  0.413500  2.928138e+05 -0.006220   0.415075   RNDR-USDT  1.574617e-03
# 74  0.003010  8.298926e+07 -0.000049   0.003026   DMTR-USDT  1.571014e-05
# 74  0.217790  1.080614e+05 -0.002605   0.218675    MLK-USDT  8.849430e-04
#
#      Percent  RawPercent  250Fees  5kFees  10kFees  250Profit   5kProfit  \
# 74  1.238568    0.012386      2.0    40.0     50.0   1.096421  21.928414
# 74  1.323351    0.013234      2.0    40.0     50.0   1.308377  26.167540
# 74  0.341317    0.003413      2.0    40.0     50.0  -1.146709 -22.934171
# 74  0.993944    0.009939      2.0    40.0     50.0   0.484860   9.697197
# 74  0.203553    0.002036      2.0    40.0     50.0  -1.491116 -29.822326
# ..       ...         ...      ...     ...      ...        ...        ...
# 74  0.012846    0.000128      2.0    40.0     50.0  -1.967885 -39.357704
# 74  1.320619    0.013206      2.0    40.0     50.0   1.301548  26.030951
# 74  0.380802    0.003808      2.0    40.0     50.0  -1.047994 -20.959889
# 74  0.521932    0.005219      2.0    40.0     50.0  -0.695171 -13.903425
# 74  0.406329    0.004063      2.0    40.0     50.0  -0.984179 -19.683572
#
#     10k0Profit
# 74   73.856828
# 74   82.335079
# 74  -15.868341
# 74   49.394393
# 74  -29.644651
# ..         ...
# 74  -48.715409
# 74   82.061903
# 74  -11.919778
# 74    2.193151
# 74   -9.367144
#
# [232 rows x 14 columns]

# %%
with open(data_path, 'w', encoding = 'utf-8-sig') as f:
  df_trades.to_csv(f)

# %%
model.save(model_path)
