# %%
# %load_ext autoreload
# %autoreload 2
import warnings
import random
import time
import pandas as pd
import numpy as np
import yfinance as yf
from plotly.offline import init_notebook_mode
from machine_learning_finance import get_coin_data_frames, attach_markers, generate_probability, \
    calc_durations_with_extremes, prob_chart, plot_full_analysis, calculate_and_graph_duration_probabilities, \
    calculate_and_graph_price_probabilities

init_notebook_mode(connected=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ledger = pd.read_csv("../data/env_SPY_guided.csv")
ledger
# Out:
#     Unnamed: 0        Date   Side Action  Profit_Percent  Profit_Actual  \
# 0            0  2021-11-16   long  enter        0.000000       0.000000
# 1            0  2021-12-31   long   exit        1.210363      45.375186
# 2            0  2021-12-31  short  enter        0.000000       0.000000
# 3            0  2022-01-26  short   exit        8.754419     409.015019
# 4            0  2022-01-26   long  enter        0.000000       0.000000
# 5            0  2022-02-02   long   exit        5.530943     253.603817
# 6            0  2022-02-02  short  enter        0.000000       0.000000
# 7            0  2022-02-24  short   exit        6.351813     310.849671
# 8            0  2022-02-24   long  enter        0.000000       0.000000
# 9            0  2022-03-28   long   exit        6.446420     320.819319
# 10           0  2022-03-28  short  enter        0.000000       0.000000
# 11           0  2022-05-09  short   exit       12.664778     630.432119
# 12           0  2022-05-09   long  enter        0.000000       0.000000
# 13           0  2022-06-02   long   exit        4.827084     275.374372
# 14           0  2022-06-02  short  enter        0.000000       0.000000
# 15           0  2022-06-13  short   exit       10.155972     586.138557
# 16           0  2022-06-13   long  enter        0.000000       0.000000
# 17           0  2022-08-10   long   exit       11.997331     798.829477
# 18           0  2022-08-10  short  enter        0.000000       0.000000
# 19           0  2022-09-21  short   exit       10.143093     757.315180
# 20           0  2022-09-21   long  enter        0.000000       0.000000
# 21           0  2022-10-28   long   exit        3.081686     236.807970
# 22           0  2022-10-28  short  enter        0.000000       0.000000
#
#           Fee        Value       Price
# 0   12.500000  4692.799988  473.972799
# 1   11.992740  4797.095914  479.709591
# 2   11.992740  4844.591913  479.709591
# 3   10.942845  5217.053778  437.713805
# 4   13.042634  4767.180054  437.713805
# 5   12.702896  5081.158568  461.923506
# 6   12.702896  5131.467068  461.923506
# 7   11.896032  5403.904271  432.582988
# 8   13.509761  5139.599854  432.582988
# 9   13.814073  5525.629244  460.469104
# 10  13.814073  5575.779345  460.469104
# 11  11.059172  6167.120536  402.151714
# 12  15.417801  5972.550201  402.151714
# 13  15.808647  6323.458722  421.563915
# 14  15.808647  6381.893324  421.563915
# 15  13.256250  6922.853529  378.750000
# 16  17.307134  6750.000000  378.750000
# 17  19.088545  7635.418022  424.189890
# 18  19.088545  7711.016221  424.189890
# 19  17.152376  8409.885579  381.163915
# 20  21.024714  8302.580322  381.163915
# 21  21.610060  8644.024156  392.910189
# 22  21.610060  8729.608553  392.910189

# %%
tickerObj = yf.download(tickers="SPY", interval="1d")
df_raw = pd.DataFrame(tickerObj)
df_raw = df_raw.tail(365)

trend, prob_above_trend, prob_below_trend, volatility, model = generate_probability(df_raw)

df_raw = attach_markers(df_raw, trend, prob_above_trend)
df_durations = calc_durations_with_extremes(df_raw)
plot_full_analysis(df_raw, trend, prob_above_trend, prob_below_trend, model, df_durations, ledger)
# Out:
# [*********************100%***********************]  1 of 1 completed
# <div>                            <div id="37ddc7ff-bade-4533-bc43-7562a9184525" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37ddc7ff-bade-4533-bc43-7562a9184525")) {                    Plotly.newPlot(                        "37ddc7ff-bade-4533-bc43-7562a9184525",                        [{"mode":"lines","name":"Value","x":["2021-11-16T00:00:00","2021-11-17T00:00:00","2021-11-18T00:00:00","2021-11-19T00:00:00","2021-11-22T00:00:00","2021-11-23T00:00:00","2021-11-24T00:00:00","2021-11-26T00:00:00","2021-11-29T00:00:00","2021-11-30T00:00:00","2021-12-01T00:00:00","2021-12-02T00:00:00","2021-12-03T00:00:00","2021-12-06T00:00:00","2021-12-07T00:00:00","2021-12-08T00:00:00","2021-12-09T00:00:00","2021-12-10T00:00:00","2021-12-13T00:00:00","2021-12-14T00:00:00","2021-12-15T00:00:00","2021-12-16T00:00:00","2021-12-17T00:00:00","2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-19T00:00:00","2022-05-20T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05-26T00:00:00","2022-05-27T00:00:00","2022-05-31T00:00:00","2022-06-01T00:00:00","2022-06-02T00:00:00","2022-06-03T00:00:00","2022-06-06T00:00:00","2022-06-07T00:00:00","2022-06-08T00:00:00","2022-06-09T00:00:00","2022-06-10T00:00:00","2022-06-13T00:00:00","2022-06-14T00:00:00","2022-06-15T00:00:00","2022-06-16T00:00:00","2022-06-17T00:00:00","2022-06-21T00:00:00","2022-06-22T00:00:00","2022-06-23T00:00:00","2022-06-24T00:00:00","2022-06-27T00:00:00","2022-06-28T00:00:00","2022-06-29T00:00:00","2022-06-30T00:00:00"," ...
