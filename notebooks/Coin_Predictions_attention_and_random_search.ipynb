# %% [markdown]
# <a href="https://colab.research.google.com/github/j03m/lstm-price-predictor/blob/main/Coin_Predictions_attention_and_random_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMPORT DATASETS AND LIBRARIES

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import plotly.express as px
from copy import copy
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import plotly.figure_factory as ff
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, confusion_matrix, classification_report, accuracy_score, f1_score
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
import requests
from requests.exceptions import HTTPError
import json as js
from datetime import datetime, timedelta 
import time
from os.path import exists
from decimal import *
from sklearn.model_selection import RandomizedSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from keras import backend as K

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %% [markdown]
# #Library

# %%
# Function to plot interactive plots using Plotly Express
sc = MinMaxScaler()
num_features = 3
coin_base = False
ku_coin = True
COINBASE_REST_API = 'https://api.pro.coinbase.com' 
COINBASE_PRODUCTS = COINBASE_REST_API+'/products'
KUCOIN_REST_API = "https://api.kucoin.com"
KUCOIN_PRODUCTS = KUCOIN_REST_API+ "/api/v1/market/allTickers"
KUCOIN_CANDLES = KUCOIN_REST_API+ "/api/v1/market/candles"

data_path = '/content/drive/My Drive/output.csv'
model_path = "/content/drive/My Drive/model_ohlc.h5"

def interactive_plot(df, title):
  fig = px.line(title = title)
  for i in df.columns[1:]:
    fig.add_scatter(x = df['Date'], y = df[i], name = i)
  fig.show()

def get_single_stock(price_df, vol_df, name):
    return pd.DataFrame({'Date': price_df['Date'], 'Close': price_df[name], 'Volume': vol_df[name]})

def scale_data(data):
  # Scale the data
  scaled_data = sc.fit_transform(data)
  return scaled_data

def sort_date(pric_df):
  pric_df = pric_df.sort_values(by = ['Date'])
  return pric_df

def append_price_dif(df):
  df['Target'] = df['Close'].shift(-1)
  df['Diff'] = df['Target'] - df['Close']
  df = df[:-1]
  return df

def append_price_dif_(df):
  df['Target'] = df['Close'].shift(-1)
  df['Diff'] = df['Target'] - df['Close']
  return df

def append_15d_slope(df):
  df['15Close'] = df['Close'].shift(15)
  df['15Date'] = df['Date'].shift(15)
  df['Trend'] = (df['Close'] - df['15Close']) / 15
  df = df[15:]
  return df

def show_plot(data, title):
  plt.figure(figsize = (13, 5))
  plt.plot(data, linewidth = 3)
  plt.title(title)
  plt.grid()

def build_model(features, outcomes):
  # Create the model
  inputs = keras.layers.Input(shape=(features,outcomes))
  x = keras.layers.LSTM(150, return_sequences= True)(inputs)
  x = keras.layers.Dropout(0.3)(x)
  x = keras.layers.LSTM(150, return_sequences=True)(x)
  x = keras.layers.Dropout(0.3)(x)
  x = keras.layers.LSTM(150)(x)
  outputs = keras.layers.Dense(1, activation='linear')(x)

  model = keras.Model(inputs=inputs, outputs=outputs)
  model.compile(optimizer='adam', loss="mse")
  return model

def connect(url, params):   
  response = requests.get(url,params)
  response.raise_for_status()
  return response

def coinbase_json_to_df(delta, product, granularity='86400'):
  start_date = (datetime.today() - timedelta(seconds=delta*int(granularity))).isoformat()
  end_date = datetime.now().isoformat()
  # Please refer to the coinbase documentation on the expected parameters
  params = {'start':start_date, 'end':end_date, 'granularity':granularity}
  response = connect(COINBASE_PRODUCTS+'/' + product + '/candles', params)
  response_text = response.text
  df_history = pd.read_json(response_text)
  # Add column names in line with the Coinbase Pro documentation
  df_history.columns = ['time','low','high','open','close','volume']
  df_history['time'] = [datetime.fromtimestamp(x) for x in df_history['time']]
  return df_history

def ku_coin_json_to_df(delta, product, granularity='86400'):
  granularity = int(granularity)
  start_date = (datetime.today() - timedelta(seconds=delta*granularity))
  end_date = datetime.now()

  # Please refer to the kucoin documentation on the expected parameters
  params = {'startAt':int(start_date.timestamp()), 'endAt':int(end_date.timestamp()), 'type':gran_to_string(granularity), 'symbol':product}
  response = connect(KUCOIN_CANDLES, params)
  response_text = response.text
  response_data = js.loads(response_text);
  if (response_data["code"] != "200000"):
    raise Exception("Illegal response: " + response_text)
  
  df_history = pd.DataFrame(response_data["data"])

  # kucoin is weird in that they don't have candles for everything. IF we don't have the requested
  # number of bars here, it throws off the whole algo. I don't want to try and project so we 
  # just won't trade those instruments
  got_bars = len(df_history)
  if ( got_bars < delta):
    raise Exception("Requested:" + str(delta) + " bars " + " but only got:" + str(got_bars))

  df_history.columns = ['time','open','close','high','low','volume', 'amount']
  df_history['time'] = [datetime.fromtimestamp(int(x)) for x in df_history['time']]
  df_history['open'] = [float(x) for x in df_history['open']]
  df_history['close'] = [float(x) for x in df_history['close']]
  df_history['high'] = [float(x) for x in df_history['high']]
  df_history['low'] = [float(x) for x in df_history['low']]
  df_history['low'] = [float(x) for x in df_history['low']]
  df_history['volume'] = [float(x) for x in df_history['volume']]
  df_history['amount'] = [float(x) for x in df_history['amount']]
  return df_history
  
def gran_to_string(granularity):
  #todo implement this actually
  return "1day"

def get_coin_data_frames(time, product, granularity='86400'):
  if coin_base:
    df_raw = coinbase_json_to_df(time, product, granularity)
  else:
    df_raw = ku_coin_json_to_df(time, product, granularity)

  df_btc_history = df_raw
  if len(df_btc_history.index) == 0:
    print("No data for ", product)
  
  df_btc_history = df_btc_history.rename(columns={"time":"Date", "close":"Close", "volume":"Volume"})
  df_btc_history = sort_date(df_btc_history)
  df_btc_history = df_btc_history.drop(columns={"high", "low", "open"})
  df_btc_history = append_price_dif_(df_btc_history)
  df_btc_history = append_15d_slope(df_btc_history)
  df_btc_features = df_btc_history[["Close", "Volume", "Trend"]]
  df_history_scaled = sc.fit_transform(df_btc_features)
  return [df_btc_history, df_btc_features, df_history_scaled, df_raw]

def build_profit_estimate(predicted, df_btc_history):
  df_predicted_chart = pd.DataFrame();
  df_predicted_chart["Date"] = df_btc_history["Date"]
  df_predicted_chart["Predicted"] = predicted
  df_predicted_chart["Predicted-Target"] = df_predicted_chart["Predicted"].shift(-1)
  df_predicted_chart["Predicted-Diff"] = df_predicted_chart["Predicted-Target"] - df_predicted_chart["Predicted"]
  df_predicted_chart["Should-Trade"] = np.where(df_predicted_chart["Predicted-Diff"] > 0, True, False)
  df_predicted_chart["RealDiff"] = df_btc_history["Diff"]
  df_predicted_chart["Percent"] = df_predicted_chart["RealDiff"] / df_btc_history["Close"]
  df_predicted_chart["Profit"] = np.where(df_predicted_chart["Should-Trade"] > 0, df_predicted_chart["Percent"] * budget, 0)
  profit = df_predicted_chart["Profit"].sum()
  return [df_predicted_chart, profit]

def debug_prediction_frame(predicted, df_history, df_history_scaled):
  df_predicted_chart = pd.DataFrame();
  df_predicted_chart["Date"] = df_history["Date"]
  df_predicted_chart["Predicted"] = predicted
  df_predicted_chart["Original"] = df_history_scaled[:,0]
  df_predicted_chart["Original-Target"] = df_history_scaled[:,2]
  df_predicted_chart["Target-Date"] = df_predicted_chart["Date"].shift(-1)
  df_predicted_chart["Predicted-Diff"] = df_predicted_chart["Predicted"] - df_predicted_chart["Original"]
  df_predicted_chart["Actual-Diff"] = df_predicted_chart["Original-Target"] - df_predicted_chart["Original"]
  df_predicted_chart["Should-Trade"] = np.where(df_predicted_chart["Predicted-Diff"] > 0, True, False)
  df_predicted_chart["Close"] = df_history["Close"]
  df_predicted_chart["Target"] = df_history["Target"]
  df_predicted_chart["RealDiff"] = df_history["Diff"]
  df_predicted_chart["Percent"] = df_predicted_chart["RealDiff"] / df_predicted_chart["Close"]
  df_predicted_chart["Profit"] = np.where(df_predicted_chart["Should-Trade"] > 0, df_predicted_chart["Percent"] * budget, 0)
  return df_predicted_chart

def get_all_products():
  if coin_base:
    return get_all_coinbase_products()
  
  if ku_coin:
    return get_all_kucoin_products()

def get_all_kucoin_products():
  response = connect(KUCOIN_PRODUCTS, {})
  products = js.loads(response.text)
  df_products = pd.DataFrame(products["data"]["ticker"])
  df_products = df_products.rename(columns={"symbol":"id"})
  return df_products

def get_all_coinbase_products():
  response = connect(COINBASE_PRODUCTS, {})
  response_text = response.text
  df_products = pd.read_json(response_text)
  return df_products

def predict_trade(product, bars):
  [df_full, df_features, npa_scaled, df_raw] = get_coin_data_frames(bars, product)
  predicted = model.predict(npa_scaled).flatten()
  
  #convert to data frames that have the correct shape for being unscaled
  df_scaled = pd.DataFrame(npa_scaled, columns = ["Close", "Volume", "Trend"])
  
  # I want to believe that scaling happens on a per column basis, we only care about
  # price here so we will dummy out volume and trend and use the scaler on it
  # this kinda sucks, if we add features we'll need to add them here for unscaling
  df_temp = pd.DataFrame(predicted, columns = ["Close"])
  df_temp["Volume"] = 0
  df_temp["Trend"] = 0
  
  # unscale them both
  df_temp = pd.DataFrame(sc.inverse_transform(df_temp), columns = ["Close", "Volume", "Trend"])
  df_trade = pd.DataFrame(sc.inverse_transform(df_scaled), columns = ["Close", "Volume", "Trend"])
  
  # add predicted
  df_trade["Predicted"] = df_temp["Close"]
  df_trade = df_trade.tail(1)

  # add the product, derive a move and percent
  df_trade["Product"] = row.id;
  df_trade["Move"] = df_trade["Predicted"] - df_trade["Close"]
  df_trade["Percent"] = (df_trade["Move"] / df_trade["Close"]) * 100
  df_trade["RawPercent"] = df_trade["Move"] / df_trade["Close"]
  df_trade["250Fees"] = (250 * 0.004) * 2
  df_trade["5kFees"] = (5000 * 0.004) * 2
  df_trade["10kFees"] = (10000 * 0.0025) * 2
  df_trade["250Profit"] = (250 * df_trade["RawPercent"]) - df_trade["250Fees"] 
  df_trade["5kProfit"] = (5000 * df_trade["RawPercent"]) - df_trade["5kFees"]
  df_trade["10k0Profit"] = (10000 * df_trade["RawPercent"]) - df_trade["10kFees"]
  return df_trade

def get_training_set_for(ticker):
  target_df = get_single_stock(all_stocks_price_df, all_stocks_vol_df, ticker)
  target_df = append_price_dif(target_df)
  target_df = append_15d_slope(target_df)
  features = target_df[["Close", "Volume", "Trend", "Target"]]
  scaled_features = scale_data(features)
  X = []
  y = []
  for i in range(0, len(target_df)):
    X.append(scaled_features [i][0:num_features])
    y.append(scaled_features [i][num_features])
  
  X = np.asarray(X)
  y = np.asarray(y)
  return [scaled_features, X, y]
  
def train_model(model, X, y):

  # One day we might need test, but for now we don't we can use another
  # time series, we have so many
  # Split the data
  #split = int(0.7 * len(X))
  #X_train = X[:split]
  #y_train = y[:split]
  #X_test = X[split:]
  #y_test = y[split:]

  # Reshape the 1D arrays to 3D arrays to feed in the model
  X_train = np.reshape(X, (X.shape[0], X.shape[1], 1))
  
  history = model.fit(
      X_train, y,
      epochs = 20,
      batch_size = 32,
      validation_split = 0.2
  )
  return [model, history]

#pull training data 
all_stocks_price_df = sort_date(pd.read_csv('/content/drive/My Drive/Colab Notebooks/stock.csv'))
all_stocks_vol_df = sort_date(pd.read_csv("/content/drive/My Drive/Colab Notebooks/stock_volume.csv"))

# %% [markdown]
# # Get or Train a Model

# %%
def create_attention_layer_lstm():

  class AttentionLayer(keras.layers.Layer):
      def __init__(self, **kwargs):
          super(AttentionLayer, self).__init__(**kwargs)

      def build(self, input_shape):
          self.W = self.add_weight(name='att_weight', 
                                  shape=(input_shape[-1], 1),
                                  initializer='normal',
                                  trainable=True)
          self.b = self.add_weight(name='att_bias',
                                  shape=(input_shape[1], 1),
                                  initializer='zeros',
                                  trainable=True)        
          super(AttentionLayer, self).build(input_shape)

      def call(self, inputs):
          e = K.tanh(K.dot(inputs, self.W) + self.b)
          a = K.softmax(e, axis=1)
          output = inputs * a
          return K.sum(output, axis=1)

      def compute_output_shape(self, input_shape):
          return (input_shape[0], input_shape[-1])


  inputs = keras.Input(shape=(3, 1))

  # Define the LSTM layer
  lstm_out = keras.layers.LSTM(32, return_sequences=True)(inputs)

  # Define the attention layer
  attention = AttentionLayer()(lstm_out)

  # Define the output layer
  output = keras.layers.Dense(1, activation='softmax')(attention)

  # Create the model
  model = keras.Model(inputs=inputs, outputs=output)
  return model

# %%
def random_search_model_params():
  [scaled_features, X, y] = get_training_set_for("sp500")  

  def build_variable_length_model(num_layers, num_units):
    features = 3
    outcomes = 1
    model = keras.models.Sequential()
    for i in range(num_layers):
      model.add(keras.layers.LSTM(units=num_units, input_shape=(features, outcomes)))
      model.add(keras.layers.Dense(1))
      model.compile(loss='mean_squared_error', optimizer='adam', metrics=["accuracy"])
    return model

  def random_search_optimal_model():
    # Create the model wrapper
    model = KerasClassifier(build_fn=build_variable_length_model)

    # Define the hyperparameter space
    param_grid = {
    'num_layers': [1, 2, 3],
    'num_units': [32, 64, 128]
    }

    # Create the random search object
    random_search = RandomizedSearchCV(estimator=model, param_distributions=param_grid, cv=5)

    # Fit the random search object to the data
    random_search.fit(X, y)

    # Print the best set of hyperparameters
    print(random_search.best_params_)

  random_search_optimal_model()

# %%
model = None
file_exists = exists(model_path)

#if file_exists:
#  print("hello")
#  model = keras.models.load_model(model_path)
#else:

[scaled_features, X, y] = get_training_set_for("sp500")  
model_orig = build_model(num_features, 1)
model_searched = create_attention_layer_lstm()
[model_orig, history] = train_model(model_orig, X, y)
[model_searched, history] = train_model(model_orig, X, y)
[btc_history, df_btc_features, df_history_scaled, df_raw] = get_coin_data_frames(180, "BTC-USDT")
loss1 = model_orig.evaluate(df_history_scaled)
loss2 = model_searched.evaluate(df_history_scaled)
print("loss1=", loss1, " loss2=", loss2)
# Out:
# Epoch 1/20
# 54/54 [==============================] - 8s 52ms/step - loss: 0.0373 - val_loss: 0.0051
# Epoch 2/20
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0022 - val_loss: 0.0071
# Epoch 3/20
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0015 - val_loss: 0.0043
# Epoch 4/20
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 5/20
# 54/54 [==============================] - 2s 29ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 6/20
# 54/54 [==============================] - 2s 28ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 7/20
# 54/54 [==============================] - 1s 27ms/step - loss: 0.0010 - val_loss: 0.0031
# Epoch 8/20
# 54/54 [==============================] - 2s 29ms/step - loss: 9.2137e-04 - val_loss: 0.0033
# Epoch 9/20
# 54/54 [==============================] - 1s 26ms/step - loss: 8.9193e-04 - val_loss: 0.0023
# Epoch 10/20
# 54/54 [==============================] - 1s 28ms/step - loss: 7.6346e-04 - val_loss: 0.0020
# Epoch 11/20
# 54/54 [==============================] - 1s 27ms/step - loss: 7.6937e-04 - val_loss: 0.0020
# Epoch 12/20
# 54/54 [==============================] - 2s 28ms/step - loss: 6.8282e-04 - val_loss: 0.0025
# Epoch 13/20
# 54/54 [==============================] - 1s 27ms/step - loss: 5.7677e-04 - val_loss: 0.0022
# Epoch 14/20
# 54/54 [==============================] - 2s 29ms/step - loss: 6.0122e-04 - val_loss: 0.0015
# Epoch 15/20
# 54/54 [==============================] - 1s 26ms/step - loss: 5.3365e-04 - val_loss: 0.0015
# Epoch 16/20
# 54/54 [==============================] - 1s 26ms/step - loss: 5.6282e-04 - val_loss: 0.0018
# Epoch 17/20
# 54/54 [==============================] - 1s 26ms/step - loss: 4.7609e-04 - val_loss: 0.0012
# Epoch 18/20
# 54/54 [==============================] - 1s 26ms/step - loss: 4.3848e-04 - val_loss: 0.0012
# Epoch 19/20
# 54/54 [==============================] - 2s 28ms/step - loss: 4.5289e-04 - val_loss: 0.0013
# Epoch 20/20
# 54/54 [==============================] - 2s 31ms/step - loss: 4.4102e-04 - val_loss: 0.0013
# Epoch 1/20
# 54/54 [==============================] - 1s 27ms/step - loss: 3.9829e-04 - val_loss: 0.0010
# Epoch 2/20
# 54/54 [==============================] - 1s 26ms/step - loss: 3.8113e-04 - val_loss: 0.0010
# Epoch 3/20
# 54/54 [==============================] - 1s 27ms/step - loss: 3.1995e-04 - val_loss: 0.0015
# Epoch 4/20
# 54/54 [==============================] - 1s 26ms/step - loss: 4.8309e-04 - val_loss: 0.0037
# Epoch 5/20
# 54/54 [==============================] - 2s 31ms/step - loss: 3.7182e-04 - val_loss: 0.0017
# Epoch 6/20
# 54/54 [==============================] - 2s 32ms/step - loss: 4.9379e-04 - val_loss: 0.0060
# Epoch 7/20
# 54/54 [==============================] - 1s 26ms/step - loss: 4.2558e-04 - val_loss: 0.0011
# Epoch 8/20
# 54/54 [==============================] - 1s 26ms/step - loss: 3.8145e-04 - val_loss: 0.0017
# Epoch 9/20
# 54/54 [==============================] - 1s 26ms/step - loss: 3.6846e-04 - val_loss: 0.0012
# Epoch 10/20
# 54/54 [==============================] - 1s 26ms/step - loss: 3.1596e-04 - val_loss: 0.0011
# Epoch 11/20
# 54/54 [==============================] - 1s 26ms/step - loss: 3.8913e-04 - val_loss: 0.0014
# Epoch 12/20
# 54/54 [==============================] - 1s 28ms/step - loss: 3.8317e-04 - val_loss: 0.0014
# Epoch 13/20
# 54/54 [==============================] - 2s 29ms/step - loss: 4.4037e-04 - val_loss: 0.0029
# Epoch 14/20
# 54/54 [==============================] - 2s 30ms/step - loss: 3.9689e-04 - val_loss: 0.0013
# Epoch 15/20
# 54/54 [==============================] - 2s 28ms/step - loss: 3.6829e-04 - val_loss: 0.0013
# Epoch 16/20
# 54/54 [==============================] - 1s 27ms/step - loss: 3.2191e-04 - val_loss: 0.0013
# Epoch 17/20
# 54/54 [==============================] - 1s 26ms/step - loss: 2.9468e-04 - val_loss: 0.0015
# Epoch 18/20
# 54/54 [==============================] - 2s 29ms/step - loss: 3.0645e-04 - val_loss: 0.0022
# Epoch 19/20
# 54/54 [==============================] - 2s 29ms/step - loss: 3.6642e-04 - val_loss: 0.0013
# Epoch 20/20
# 54/54 [==============================] - 1s 27ms/step - loss: 3.4797e-04 - val_loss: 0.0013
# 6/6 [==============================] - 1s 2ms/step - loss: 0.0000e+00
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# loss1= 0.0  loss2= 0.0

# %%
# additional training?
if 0:
  [scaled_features, X, y] = get_training_set_for("IBM")  
  [model, history] = train_model(model, X, y)

# %% [markdown]
# # Visualize and Backtest

# %%
budget = 5000
[btc_history, df_btc_features, df_history_scaled, df_raw] = get_coin_data_frames(180, "FCON-USDT")
predicted = model_searched.predict(df_history_scaled).flatten()
predicted2 = model_orig.predict(df_history_scaled).flatten()
[df_profit, profit] = build_profit_estimate(predicted, btc_history)
[df_profit, profit2] = build_profit_estimate(predicted2, btc_history)
df_chart = debug_prediction_frame(predicted, btc_history, df_history_scaled)
df_chart["Predicted-Orig"] = predicted2
interactive_plot(df_chart[["Date","Original", "Predicted-Orig"]], "Wtf")
interactive_plot(df_chart[["Date","Original", "Predicted"]], "Wtf")
print("Profit searched:", profit)
print("Profit orig:", profit2)
df_chart
# Out:
# 6/6 [==============================] - 2s 8ms/step
# 6/6 [==============================] - 0s 9ms/step
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b9dd43e6-6588-4f2a-a46b-bc579c0a78eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9dd43e6-6588-4f2a-a46b-bc579c0a78eb")) {                    Plotly.newPlot(                        "b9dd43e6-6588-4f2a-a46b-bc579c0a78eb",                        [{"name":"Original","x":["2022-07-18T00:00:00","2022-07-19T00:00:00","2022-07-20T00:00:00","2022-07-21T00:00:00","2022-07-22T00:00:00","2022-07-23T00:00:00","2022-07-24T00:00:00","2022-07-25T00:00:00","2022-07-26T00:00:00","2022-07-27T00:00:00","2022-07-28T00:00:00","2022-07-29T00:00:00","2022-07-30T00:00:00","2022-07-31T00:00:00","2022-08-01T00:00:00","2022-08-02T00:00:00","2022-08-03T00:00:00","2022-08-04T00:00:00","2022-08-05T00:00:00","2022-08-06T00:00:00","2022-08-07T00:00:00","2022-08-08T00:00:00","2022-08-09T00:00:00","2022-08-10T00:00:00","2022-08-11T00:00:00","2022-08-12T00:00:00","2022-08-13T00:00:00","2022-08-14T00:00:00","2022-08-15T00:00:00","2022-08-16T00:00:00","2022-08-17T00:00:00","2022-08-18T00:00:00","2022-08-19T00:00:00","2022-08-20T00:00:00","2022-08-21T00:00:00","2022-08-22T00:00:00","2022-08-23T00:00:00","2022-08-24T00:00:00","2022-08-25T00:00:00","2022-08-26T00:00:00","2022-08-27T00:00:00","2022-08-28T00:00:00","2022-08-29T00:00:00","2022-08-30T00:00:00","2022-08-31T00:00:00","2022-09-01T00:00:00","2022-09-02T00:00:00","2022-09-03T00:00:00","2022-09-04T00:00:00","2022-09-05T00:00:00","2022-09-06T00:00:00","2022-09-07T00:00:00","2022-09-08T00:00:00","2022-09-09T00:00:00","2022-09-10T00:00:00","2022-09-11T00:00:00","2022-09-12T00:00:00","2022-09-13T00:00:00","2022-09-14T00:00:00","2022-09-15T00:00:00","2022-09-16T00:00:00","2022-09-17T00:00:00","2022-09-18T00:00:00","2022-09-19T00:00:00","2022-09-20T00:00:00","2022-09-21T00:00:00","2022-09-22T00:00:00","2022-09-23T00:00:00","2022-09-24T00:00:00","2022-09-25T00:00:00","2022-09-26T00:00:00","2022-09-27T00:00:00","2022-09-28T00:00:00","2022-09-29T00:00:00","2022-09-30T00:00:00","2022-10-01T00:00:00","2022-10-02T00:00:00","2022-10-03T00:00:00","2022-10-04T00:00:00","2022-10-05T00:00:00","2022-10-06T00:00:00","2022-10-07T00:00:00","2022-10-08T00:00:00","2022-10-09T00:00:00","2022-10-10T00:00:00","2022-10-11T00:00:00","2022-10-12T00:00:00","2022-10-13T00:00:00","2022-10-14T00:00:00","2022-10-15T00:00:00","2022-10-16T00:00:00","2022-10-17T00:00:00","2022-10-18T00:00:00","2022-10-19T00:00:00","2022-10-20T00:00:00","2022-10-21T00:00:00","2022-10-22T00:00:00","2022-10-23T00:00:00","2022-10-24T00:00:00","2022-10-25T00:00:00","2022-10-26T00:00:00","2022-10-27T00:00:00","2022-10-28T00:00:00","2022-10-29T00:00:00","2022-10-30T00:00:00","2022-10-31T00:00:00","2022-11-01T00:00:00","2022-11-02T00:00:00","2022-11-03T00:00:00","2022-11-04T00:00:00","2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00","2022-11-10T00:00:00","2022-11-11T00:00:00","2022-11-12T00:00:00","2022-11-13T00:00:00","2022-11-14T00:00:00","2022-11-15T00:00:00","2022-11-16T00:00:00","2022-11-17T00:00:00","2022-11-18T00:00:00","2022-11-19T00:00:00","2022-11-20T00:00:00","2022-11-21T00:00:00","2022-11-22T00:00:00","2022-11-23T00:00:00","2022-11-24T00:00:00","2022-11-25T00:00:00","2022-11-26T00:00:00","2022-11-27T00:00:00","2022-11-28T00:00:00","2022-11-29T00:00:00","2022-11-30T00:00:00","2022-12-01T00:00:00","2022-12-02T00:00:00","2022-12-03T00:00:00","2022-12-04T00:00:00","2022-12-05T00:00:00","2022-12-06T00:00:00","2022-12-07T00:00:00","2022-12-08T00:00:00","2022-12-09T00:00:00","2022-12-10T00:00:00","2022-12-11T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="82ad7e4c-3b9c-474b-b906-05c0a417d933" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82ad7e4c-3b9c-474b-b906-05c0a417d933")) {                    Plotly.newPlot(                        "82ad7e4c-3b9c-474b-b906-05c0a417d933",                        [{"name":"Original","x":["2022-07-18T00:00:00","2022-07-19T00:00:00","2022-07-20T00:00:00","2022-07-21T00:00:00","2022-07-22T00:00:00","2022-07-23T00:00:00","2022-07-24T00:00:00","2022-07-25T00:00:00","2022-07-26T00:00:00","2022-07-27T00:00:00","2022-07-28T00:00:00","2022-07-29T00:00:00","2022-07-30T00:00:00","2022-07-31T00:00:00","2022-08-01T00:00:00","2022-08-02T00:00:00","2022-08-03T00:00:00","2022-08-04T00:00:00","2022-08-05T00:00:00","2022-08-06T00:00:00","2022-08-07T00:00:00","2022-08-08T00:00:00","2022-08-09T00:00:00","2022-08-10T00:00:00","2022-08-11T00:00:00","2022-08-12T00:00:00","2022-08-13T00:00:00","2022-08-14T00:00:00","2022-08-15T00:00:00","2022-08-16T00:00:00","2022-08-17T00:00:00","2022-08-18T00:00:00","2022-08-19T00:00:00","2022-08-20T00:00:00","2022-08-21T00:00:00","2022-08-22T00:00:00","2022-08-23T00:00:00","2022-08-24T00:00:00","2022-08-25T00:00:00","2022-08-26T00:00:00","2022-08-27T00:00:00","2022-08-28T00:00:00","2022-08-29T00:00:00","2022-08-30T00:00:00","2022-08-31T00:00:00","2022-09-01T00:00:00","2022-09-02T00:00:00","2022-09-03T00:00:00","2022-09-04T00:00:00","2022-09-05T00:00:00","2022-09-06T00:00:00","2022-09-07T00:00:00","2022-09-08T00:00:00","2022-09-09T00:00:00","2022-09-10T00:00:00","2022-09-11T00:00:00","2022-09-12T00:00:00","2022-09-13T00:00:00","2022-09-14T00:00:00","2022-09-15T00:00:00","2022-09-16T00:00:00","2022-09-17T00:00:00","2022-09-18T00:00:00","2022-09-19T00:00:00","2022-09-20T00:00:00","2022-09-21T00:00:00","2022-09-22T00:00:00","2022-09-23T00:00:00","2022-09-24T00:00:00","2022-09-25T00:00:00","2022-09-26T00:00:00","2022-09-27T00:00:00","2022-09-28T00:00:00","2022-09-29T00:00:00","2022-09-30T00:00:00","2022-10-01T00:00:00","2022-10-02T00:00:00","2022-10-03T00:00:00","2022-10-04T00:00:00","2022-10-05T00:00:00","2022-10-06T00:00:00","2022-10-07T00:00:00","2022-10-08T00:00:00","2022-10-09T00:00:00","2022-10-10T00:00:00","2022-10-11T00:00:00","2022-10-12T00:00:00","2022-10-13T00:00:00","2022-10-14T00:00:00","2022-10-15T00:00:00","2022-10-16T00:00:00","2022-10-17T00:00:00","2022-10-18T00:00:00","2022-10-19T00:00:00","2022-10-20T00:00:00","2022-10-21T00:00:00","2022-10-22T00:00:00","2022-10-23T00:00:00","2022-10-24T00:00:00","2022-10-25T00:00:00","2022-10-26T00:00:00","2022-10-27T00:00:00","2022-10-28T00:00:00","2022-10-29T00:00:00","2022-10-30T00:00:00","2022-10-31T00:00:00","2022-11-01T00:00:00","2022-11-02T00:00:00","2022-11-03T00:00:00","2022-11-04T00:00:00","2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00","2022-11-10T00:00:00","2022-11-11T00:00:00","2022-11-12T00:00:00","2022-11-13T00:00:00","2022-11-14T00:00:00","2022-11-15T00:00:00","2022-11-16T00:00:00","2022-11-17T00:00:00","2022-11-18T00:00:00","2022-11-19T00:00:00","2022-11-20T00:00:00","2022-11-21T00:00:00","2022-11-22T00:00:00","2022-11-23T00:00:00","2022-11-24T00:00:00","2022-11-25T00:00:00","2022-11-26T00:00:00","2022-11-27T00:00:00","2022-11-28T00:00:00","2022-11-29T00:00:00","2022-11-30T00:00:00","2022-12-01T00:00:00","2022-12-02T00:00:00","2022-12-03T00:00:00","2022-12-04T00:00:00","2022-12-05T00:00:00","2022-12-06T00:00:00","2022-12-07T00:00:00","2022-12-08T00:00:00","2022-12-09T00:00:00","2022-12-10T00:00:00","2022-12-11T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:0 ...
# Profit searched: 13063.42369568083
# Profit orig: 13063.42369568083
#           Date  Predicted  Original  Original-Target Target-Date  \
# 164 2022-07-18    0.84783   0.86496          0.37058  2022-07-19
# 163 2022-07-19    0.84748   0.86496          0.38614  2022-07-20
# 162 2022-07-20    0.82052   0.82949          0.33663  2022-07-21
# 161 2022-07-21    0.80706   0.81312          0.33380  2022-07-22
# 160 2022-07-22    0.81262   0.81994          0.34088  2022-07-23
# ..         ...        ...       ...              ...         ...
# 4   2022-12-25   -0.02428   0.00259          0.34767  2022-12-26
# 3   2022-12-26   -0.02127   0.00546          0.33649  2022-12-27
# 2   2022-12-27   -0.02591   0.00273          0.32942  2022-12-28
# 1   2022-12-28   -0.02972   0.00000          0.34272  2022-12-29
# 0   2022-12-29   -0.01965   0.00627          0.34187         NaT
#
#      Predicted-Diff  Actual-Diff  Should-Trade   Close  Target  RealDiff  \
# 164        -0.01712     -0.49438         False 0.00068 0.00068   0.00000
# 163        -0.01748     -0.47882         False 0.00068 0.00065  -0.00003
# 162        -0.00898     -0.49286         False 0.00065 0.00064  -0.00001
# 161        -0.00606     -0.47932         False 0.00064 0.00064   0.00001
# 160        -0.00732     -0.47907         False 0.00064 0.00063  -0.00002
# ..              ...          ...           ...     ...     ...       ...
# 4          -0.02687      0.34507         False 0.00004 0.00005   0.00000
# 3          -0.02672      0.33104         False 0.00005 0.00004  -0.00000
# 2          -0.02864      0.32669         False 0.00004 0.00004  -0.00000
# 1          -0.02972      0.34272         False 0.00004 0.00005   0.00000
# 0          -0.02593      0.33559         False 0.00005     NaN       NaN
#
#      Percent  Profit  Predicted-Orig
# 164  0.00000 0.00000         0.84783
# 163 -0.03840 0.00000         0.84748
# 162 -0.01843 0.00000         0.82052
# 161  0.00782 0.00000         0.80706
# 160 -0.02329 0.00000         0.81262
# ..       ...     ...             ...
# 4    0.04688 0.00000        -0.02428
# 3   -0.04264 0.00000        -0.02127
# 2   -0.04454 0.00000        -0.02591
# 1    0.10723 0.00000        -0.02972
# 0        NaN 0.00000        -0.01965
#
# [165 rows x 14 columns]

# %%
print("rscore: ", r2_score(predicted, df_history_scaled[:, 2]))
# Out:
# rscore:  0.13113149877319585

# %% [markdown]
# # Which coins are most profitable based on the above trading signals?

# %%
# download all known products and check who has the highest profit in 90 days
"""
# Fetch the top 10 and see if they predict up
df_products = get_all_products()
df_products = df_products[df_products.id.str.endswith('USD')]
df_products = df_products[df_products.trading_disabled == False]
df_products = df_products[df_products.cancel_only == False]
df_profit = pd.DataFrame();
df_profit["Product"] = [];
df_profit["Profit"] = [];
for index, row in df_products.iterrows():
  try:
    print("fetching: ", row.id)
    [df_full, df_features, df_scaled] = get_coin_data_frames_test(90, row.id)
    predicted = model.predict(df_scaled.flatten())
    [df_chart, profit] = build_profit_estimate(predicted, df_full)
    df_profit.loc[len(df_profit.index)] = [row.id, profit] 
  except Exception as inst:
    print("Error: ", inst)
  time.sleep(1)

df_profit
"""
# Out:
# '\n# Fetch the top 10 and see if they predict up\ndf_products = get_all_products()\ndf_products = df_products[df_products.id.str.endswith(\'USD\')]\ndf_products = df_products[df_products.trading_disabled == False]\ndf_products = df_products[df_products.cancel_only == False]\ndf_profit = pd.DataFrame();\ndf_profit["Product"] = [];\ndf_profit["Profit"] = [];\nfor index, row in df_products.iterrows():\n  try:\n    print("fetching: ", row.id)\n    [df_full, df_features, df_scaled] = get_coin_data_frames_test(90, row.id)\n    predicted = model.predict(df_scaled.flatten())\n    [df_chart, profit] = build_profit_estimate(predicted, df_full)\n    df_profit.loc[len(df_profit.index)] = [row.id, profit] \n  except Exception as inst:\n    print("Error: ", inst)\n  time.sleep(1)\n\ndf_profit\n'

# %% [markdown]
# # What has a buy indicator for tomorrow?

# %%
# Fetch the top 10 and see if they predict up
df_products = get_all_products()
df_products = df_products[df_products.id.str.endswith('USDT')]

if coin_base:
  df_products = df_products[df_products.trading_disabled == False]
  df_products = df_products[df_products.cancel_only == False]

df_trades = pd.DataFrame();
bars = 90
counter = 0;
for index, row in df_products.iterrows():
  try:
    print("fetching: ", row.id)
    
    df_trade = predict_trade(row.id, bars)
   
    # we need to unscale the predicted values so that we have an entry and exit point
    # entry should be roughly close and exit should be roughly predicted

    # Stick this on the end of the main dataframe
    df_trades = df_trades.append(df_trade);
    
    #counter+=1
    #if counter > 5:
    #  break
  except Exception as inst:
    #raise inst
    print("Error: ", inst)
  time.sleep(0.5)
df_trades.reset_index()
df_buys = df_trades[df_trades['Move'] > 0] 
df_shorts = df_trades[df_trades['Move'] < 0]
# Out:
# fetching:  NKN-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  GEM-USDT
# Error:  Requested:90 bars  but only got:80
# fetching:  CUSD-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  LTC3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  OAS-USDT
# Error:  Requested:90 bars  but only got:18
# fetching:  KNC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  LYM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  HAI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MITX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PDEX-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664536945&endAt=1672312945&type=1day&symbol=PDEX-USDT
# fetching:  FLAME-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  EPX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AOG-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ATOM3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AGLD-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  YLD-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  CWS-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  SENSO-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ALBT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ALICE-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664536955&endAt=1672312955&type=1day&symbol=ALICE-USDT
# fetching:  UNIC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  IHC-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  BULL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  SWASH-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  XEC-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ATOM3S-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LINA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ETC-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  RUNE-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  MPLX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  HYDRA-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664536965&endAt=1672312965&type=1day&symbol=HYDRA-USDT
# fetching:  ASTR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BCH-USDT
# 3/3 [==============================] - 0s 24ms/step
# fetching:  NGM-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  JAR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TONE-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  POSI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  EOS3L-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  KAVA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GLQ-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  VSYS-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  GAS-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664536975&endAt=1672312975&type=1day&symbol=GAS-USDT
# fetching:  APT-USDT
# Error:  Requested:90 bars  but only got:72
# fetching:  TRX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CELO-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MOOV-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  SAND-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FIDA-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664536980&endAt=1672312980&type=1day&symbol=FIDA-USDT
# fetching:  KLAY-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  T-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SUN-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  DATA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  LABS-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  BOND-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664536986&endAt=1672312986&type=1day&symbol=BOND-USDT
# fetching:  LTC3S-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  DPET-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  TARA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  DERO-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  EFX-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664536990&endAt=1672312990&type=1day&symbol=EFX-USDT
# fetching:  LDO-USDT
# 3/3 [==============================] - 0s 22ms/step
# fetching:  WOM-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  NUM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  NMR-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  TON-USDT
# Error:  Requested:90 bars  but only got:64
# fetching:  CWAR-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  AAVE-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  HIOD-USDT
# Error:  Requested:90 bars  but only got:73
# fetching:  AAVE3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HIGAZERS-USDT
# Error:  Requested:90 bars  but only got:36
# fetching:  CREDI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  LON-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  BTC3L-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TRB-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ELA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  DOGE-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ZEE-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  BICO-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PRE-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  ENS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CTI-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  LPT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  PMON-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XNL-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  EOS3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SYNR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  TLOS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  NAVI-USDT
# Error:  Requested:90 bars  but only got:31
# fetching:  WHALE-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FCD-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  USDD-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MONI-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ETH3S-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  NEO-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537020&endAt=1672313020&type=1day&symbol=NEO-USDT
# fetching:  BTC3S-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  CHZ-USDT
# 3/3 [==============================] - 0s 30ms/step
# fetching:  USDC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  DOT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PSL-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  AZERO-USDT
# Error:  Requested:90 bars  but only got:45
# fetching:  RFOX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  WXT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  APL-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  UNI3L-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  GAFI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  EOS-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  UOS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MNST-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  GMX-USDT
# Error:  Requested:90 bars  but only got:77
# fetching:  XCN-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  GHX-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  FTG-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  POLS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HISAND33-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  IOST-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537040&endAt=1672313040&type=1day&symbol=IOST-USDT
# fetching:  TVK-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AMB-USDT
# Error:  Requested:90 bars  but only got:51
# fetching:  CCD-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ETH3L-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  OUSD-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  GMEE-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  DOT3S-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  HTR-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  CFG-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  UBX-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ERTHA-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537050&endAt=1672313050&type=1day&symbol=ERTHA-USDT
# fetching:  FEAR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  NGL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BTC-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  AAVE3L-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  PLU-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SUSHI3S-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  OCEAN-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  GMB-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  CGG-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  INDI-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  SRK-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  RED-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  APE-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ERG-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ZBC-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  SDL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  REVV-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  GST-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  LOOKS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  PROM-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ARKER-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  HT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  HAPI-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  P00LS-USDT
# Error:  Requested:90 bars  but only got:80
# fetching:  ADA-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  DIA-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  HNT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ALPHA-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  DPR-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  HIODBS-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  AERGO-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CFX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DOT3L-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537080&endAt=1672313080&type=1day&symbol=DOT3L-USDT
# fetching:  SRM-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  BOLT-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ERN-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  KMD-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  RBP-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  EOSC-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  SUSHI3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BUY-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  CQT-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ISP-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  KRL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MAKI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ARX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CLV-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MAP-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ROSN-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  BTT-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  PUSH-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ZEC-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  URUS-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  SYLO-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  XTAG-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  SPA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ICX-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  AGIX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SOLVE-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537104&endAt=1672313104&type=1day&symbol=SOLVE-USDT
# fetching:  VIDT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  JASMY-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  KARA-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  WIN-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SXP-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  VID-USDT
# 3/3 [==============================] - 0s 21ms/step
# fetching:  FORESTPLUS-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  TEL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ARRR-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  MEM-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  JASMY3S-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  HEART-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  AXS3S-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CLUB-USDT
# Error:  Requested:90 bars  but only got:30
# fetching:  FCON-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  NYM-USDT
# 3/3 [==============================] - 0s 21ms/step
# fetching:  GMT3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ORAI-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  STC-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  EPK-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  HIFIDENZA-USDT
# Error:  Requested:90 bars  but only got:45
# fetching:  LTO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MJT-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  APE3L-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  ACOIN-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  IDEA-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  REN-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ANC-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  LUNC-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  XRP3S-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  CARD-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  PLATO-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  SHILL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SOUL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  DAG-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XHV-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  SAND3S-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  STG-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  XMR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TOKO-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  EVER-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  POLC-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ZEN-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ACT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  VAI-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  FTM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ZCX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  AXS3L-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537149&endAt=1672313149&type=1day&symbol=AXS3L-USDT
# fetching:  AKRO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XWG-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CKB-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  H2O-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  COV-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  MTL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  NEAR3L-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  MNET-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SKEY-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  DYDX-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  XCV-USDT
# Error:  Requested:90 bars  but only got:57
# fetching:  1EARTH-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SOL3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AUSD-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XRP3L-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  OVR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  REQ-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  SUKU-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  DAO-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  WEST-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  CIX100-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BOSON-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AMP-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  BEAT-USDT
# Error:  Requested:90 bars  but only got:44
# fetching:  GODS-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  XPR-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  LOKI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  NEAR3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  EPS-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  JAM-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ORBS-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FXS-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  RLC-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  UNFI-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  CIRUS-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  FTT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  FITFI-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  HAKA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  YFDAI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  MATIC3L-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  FKX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SAND3L-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  KAR-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  BASIC-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  XED-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  BCHSV-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SOL3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SNX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PUMLX-USDT
# Error:  Requested:90 bars  but only got:84
# fetching:  AIOZ-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PBX-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  INJ-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TIDAL-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  USDP-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  LPOOL-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  NHCT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ATOM-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MANA-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  PIAS-USDT
# Error:  Requested:90 bars  but only got:60
# fetching:  BRWL-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  ACQ-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537204&endAt=1672313204&type=1day&symbol=ACQ-USDT
# fetching:  ALT-USDT
# Error:  Requested:90 bars  but only got:29
# fetching:  FTM3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AUDIO-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  VEGA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TEM-USDT
# Error:  Requested:90 bars  but only got:2
# fetching:  SHFT-USDT
# 3/3 [==============================] - 0s 24ms/step
# fetching:  KSM-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ETH-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  STORJ-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  OPCT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HIDOODLES-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537215&endAt=1672313215&type=1day&symbol=HIDOODLES-USDT
# fetching:  HIENS4-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  EFI-USDT
# Error:  Requested:90 bars  but only got:72
# fetching:  GALAX-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  BLOK-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BURGER-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  PEOPLE-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537220&endAt=1672313220&type=1day&symbol=PEOPLE-USDT
# fetching:  CWEB-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BAL-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  SKU-USDT
# 3/3 [==============================] - 0s 21ms/step
# fetching:  BUX-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  FLOW-USDT
# 3/3 [==============================] - 0s 31ms/step
# fetching:  GALAX3S-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537226&endAt=1672313226&type=1day&symbol=GALAX3S-USDT
# fetching:  WMT-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  SUPER-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  IMX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  OLE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  CREAM-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ADA3L-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LINK3S-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  MATIC3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  PHNX-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  GARI-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PNT-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  ROAR-USDT
# 3/3 [==============================] - 0s 25ms/step
# fetching:  DSLA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SLCL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  VRA-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  WAX-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  DEXE-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SHR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LINK3L-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  GMT3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  JASMY3L-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  CEEK-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XCH-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  SDAO-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SCLP-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  HIMAYC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AI-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FORT-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  CMP-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  FRM-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  LMR-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  HISQUIGGLE-USDT
# Error:  Requested:90 bars  but only got:57
# fetching:  NTVRK-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537255&endAt=1672313255&type=1day&symbol=NTVRK-USDT
# fetching:  AURY-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HAWK-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AKT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TXA-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  CPOOL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  1INCH-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537260&endAt=1672313260&type=1day&symbol=1INCH-USDT
# fetching:  ALEPH-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  PERP-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ADA3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MNW-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ANT-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  PRMX-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  HICOOLCATS-USDT
# Error:  Requested:90 bars  but only got:15
# fetching:  MTS-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  ABBC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  ADX-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  MFT-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  CAKE-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XETA-USDT
# Error:  Requested:90 bars  but only got:81
# fetching:  NWC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DAR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AURORA-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  GAL-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537275&endAt=1672313275&type=1day&symbol=GAL-USDT
# fetching:  ONE-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  SFUND-USDT
# 3/3 [==============================] - 0s 10ms/step
# fetching:  FTM3S-USDT
# 3/3 [==============================] - 0s 19ms/step
# fetching:  SON-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  STEPWATCH-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  AVAX-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MASK-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  PIX-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  FORM-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  MV-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  GLMR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  VR-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  POKT-USDT
# Error:  Requested:90 bars  but only got:72
# fetching:  DOGE3L-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  STX-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  XPRT-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  OOE-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  SHA-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  GLCH-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  GEEQ-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  MBL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  H3RO3S-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MODEFI-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  QRDO-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  XAVA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  XYM-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LUNA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XNO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  COOHA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MLS-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  MANA3S-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DOGE3S-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CVX-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  KYL-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  EQZ-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  IOTA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  XDEFI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  DFI-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  HFT-USDT
# Error:  Requested:90 bars  but only got:53
# fetching:  CSPR-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  PUNDIX-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ELON-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  IXS-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  AXS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BNX-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  VELO-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CBC-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  KMA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TITAN-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SRBP-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  OPUL-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  VET3L-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  FRONT-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  CAS-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  CELR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  KONO-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  MTV-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CRO-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  HARD-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  WOMBAT-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  MAN-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  SOL-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  API3-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ECOX-USDT
# Error:  Requested:90 bars  but only got:53
# fetching:  YFI-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SWFTC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MARSH-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  VET3S-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  SYS-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  KOL-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537341&endAt=1672313341&type=1day&symbol=KOL-USDT
# fetching:  PLY-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MATIC-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  SWEAT-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  LTX-USDT
# 3/3 [==============================] - 0s 19ms/step
# fetching:  MTRG-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  PAXG-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SIN-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DPI-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  XRP-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  HIMEEBITS-USDT
# Error:  Requested:90 bars  but only got:59
# fetching:  BNB-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  PCX-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  PRQ-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  ALPINE-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  CARE-USDT
# Error:  Requested:90 bars  but only got:30
# fetching:  NIM-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  DYP-USDT
# 3/3 [==============================] - 0s 19ms/step
# fetching:  BOA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MAHA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GALAX3L-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  CRV-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  LOC-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  NOIA-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  EGLD-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  LSS-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  DFA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  HIENS3-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  DINO-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  KIN-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  VLX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  PBR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MANA3L-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ERSDL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SWP-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  GENS-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SHX-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GRT-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  PHA-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  UNB-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SKL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  DFYN-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  RMRK-USDT
# 3/3 [==============================] - 0s 19ms/step
# fetching:  BRISE-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  OGV-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FSN-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  LOKA-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  TRADE-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  RACEFI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  KAT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  AVA-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  COTI-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  GGG-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  WSIENNA-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  WOO-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  RACA-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  EUL-USDT
# Error:  Requested:90 bars  but only got:65
# fetching:  BUSD-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  REV3L-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  XCAD-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  ACH-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  VET-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ILV-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  LBP-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ODDZ-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  BNB3S-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537400&endAt=1672313400&type=1day&symbol=BNB3S-USDT
# fetching:  CHMB-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  HICLONEX-USDT
# Error:  Requested:90 bars  but only got:22
# fetching:  TFUEL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  METIS-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  DUSK-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537405&endAt=1672313405&type=1day&symbol=DUSK-USDT
# fetching:  TRU-USDT
# 3/3 [==============================] - 0s 21ms/step
# fetching:  ZKT-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537406&endAt=1672313406&type=1day&symbol=ZKT-USDT
# fetching:  BNC-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537407&endAt=1672313407&type=1day&symbol=BNC-USDT
# fetching:  POLX-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537408&endAt=1672313408&type=1day&symbol=POLX-USDT
# fetching:  PKF-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  LYXE-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SHIB-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537411&endAt=1672313411&type=1day&symbol=SHIB-USDT
# fetching:  ILA-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  AVAX3S-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  HIAZUKI-USDT
# Error:  Requested:90 bars  but only got:8
# fetching:  ONSTON-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  XDB-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  UNI-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FT-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  ACA-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  SWINGBY-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  LOVE-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537419&endAt=1672313419&type=1day&symbol=LOVE-USDT
# fetching:  WOOP-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  STRONG-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ARPA-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  FALCONS-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  THETA-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  HBAR-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  ETN-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  STARLY-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  KDON-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  GTC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  XTM-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  SUSHI-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  LTC-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CELT-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  CULT-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  SCRT-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537434&endAt=1672313434&type=1day&symbol=SCRT-USDT
# fetching:  TIME-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TLM-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  XCUR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  VEED-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  LINK-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  AFK-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  PLD-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  WEMIX-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  NDAU-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  APE3S-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  KDA-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537445&endAt=1672313445&type=1day&symbol=KDA-USDT
# fetching:  KICKS-USDT
# Error:  Requested:90 bars  but only got:73
# fetching:  ROSE-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ARNM-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  PEEL-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  TKY-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  XTZ-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MIR-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  EXRD-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  UFO-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ACE-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  TRVL-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  NEER-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  HBB-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  DC-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  RVN-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  BCH3L-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537459&endAt=1672313459&type=1day&symbol=BCH3L-USDT
# fetching:  OP-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  VXV-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  SOLR-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  IOI-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  DAPPT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ETHW-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  POND-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ICP-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LACE-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  BNS-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  NORD-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537470&endAt=1672313470&type=1day&symbol=NORD-USDT
# fetching:  DG-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  BNB3L-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  BAX-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  LOCG-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  QI-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  XYO-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  AVAX3L-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  DGB-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  LRC-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  EDG-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  GRIN-USDT
# 3/3 [==============================] - 0s 19ms/step
# fetching:  REEF-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ANKR-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  PEL-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  CLH-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  DAPPX-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  FLY-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  ROUTE-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  BOBA-USDT
# 3/3 [==============================] - 0s 19ms/step
# fetching:  ORN-USDT
# 3/3 [==============================] - 0s 22ms/step
# fetching:  HIPUNKS-USDT
# 3/3 [==============================] - 0s 22ms/step
# fetching:  SLIM-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  POLK-USDT
# 3/3 [==============================] - 0s 32ms/step
# fetching:  WRX-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  CTSI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  MSWAP-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  EGAME-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  FIL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  BCH3S-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  C98-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  NGC-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  RSR-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  UNI3S-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  GOVI-USDT
# 3/3 [==============================] - 0s 21ms/step
# fetching:  RBS-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  PRIMAL-USDT
# Error:  Requested:90 bars  but only got:22
# fetching:  WILD-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  CUDOS-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  NAKA-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  MXC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  NFT-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ONT-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  DERC-USDT
# Error:  Requested:90 bars  but only got:79
# fetching:  UMA-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  FORTH-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  MOVR-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  R-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  DVPN-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537515&endAt=1672313515&type=1day&symbol=DVPN-USDT
# fetching:  REVU-USDT
# 3/3 [==============================] - 0s 11ms/step
# fetching:  AR-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  USTC-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  WELL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  CTC-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537520&endAt=1672313520&type=1day&symbol=CTC-USDT
# fetching:  BEPRO-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  DREAMS-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  BAND-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  VOXEL-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  ATA-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  XLM-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537525&endAt=1672313525&type=1day&symbol=XLM-USDT
# fetching:  NRFB-USDT
# Error:  Requested:90 bars  but only got:37
# fetching:  YGG-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  BONDLY-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  POL-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  KOK-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  LAVAX-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537530&endAt=1672313530&type=1day&symbol=LAVAX-USDT
# fetching:  EQX-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  DEGO-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  MLN-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  USDJ-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  BAT-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537535&endAt=1672313535&type=1day&symbol=BAT-USDT
# fetching:  STND-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537535&endAt=1672313535&type=1day&symbol=STND-USDT
# fetching:  SFP-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  SOS-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  UNO-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ENQ-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  SLP-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  MARS4-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  XEM-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  KAI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  IOTX-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  OXT-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  PSTAKE-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  OM-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  GMM-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  RFUEL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ASD-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  KCS-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  LIT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  BSW-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  GMT-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  TOWER-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  EWT-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ADS-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537555&endAt=1672313555&type=1day&symbol=ADS-USDT
# fetching:  BIFI-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  SUTER-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  OMG-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  COCOS-USDT
# 3/3 [==============================] - 0s 23ms/step
# fetching:  FRA-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  HIFLUF-USDT
# Error:  Requested:90 bars  but only got:0
# fetching:  ZIL-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MATTER-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  TT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  XDC-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  COMP-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  BBC-USDT
# Error:  Requested:90 bars  but only got:65
# fetching:  HOTCROSS-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  PYR-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  ALGO-USDT
# 3/3 [==============================] - 0s 19ms/step
# fetching:  AMPL-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  WAVES-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  PLGR-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  MELOS-USDT
# 3/3 [==============================] - 0s 33ms/step
# fetching:  RANKER-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  DASH-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  EPIK-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  CRPT-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  HEGIC-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  LIKE-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  VISION-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  HERO-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  HIBAYC-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  SRBS-USDT
# Error:  Illegal response: {"code":"400100","msg":"This pair is not provided at present."}
# fetching:  ENJ-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  DODO-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  GLM-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  TRIAS-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  DIVI-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  TRIBL-USDT
# Error:  Requested:90 bars  but only got:78
# fetching:  WAL-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  HYVE-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  QUARTZ-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537589&endAt=1672313589&type=1day&symbol=QUARTZ-USDT
# fetching:  QUICK-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  GOM2-USDT
# Error:  429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?startAt=1664537591&endAt=1672313591&type=1day&symbol=GOM2-USDT
# fetching:  JST-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  RLY-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  ORC-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  AOA-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  TAUM-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  MC-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  OGN-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  QNT-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  NEAR-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  HIPENGUINS-USDT
# Error:  Requested:90 bars  but only got:29
# fetching:  BFC-USDT
# 3/3 [==============================] - 0s 12ms/step
# fetching:  REAP-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  CHR-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  KLV-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  TWT-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LAYER-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  MKR-USDT
# 3/3 [==============================] - 0s 14ms/step
# fetching:  STORE-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  LITH-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  FLUX-USDT
# 3/3 [==============================] - 0s 16ms/step
# fetching:  CERE-USDT
# 3/3 [==============================] - 0s 17ms/step
# fetching:  UPO-USDT
# 3/3 [==============================] - 0s 19ms/step
# fetching:  2CRZ-USDT
# 3/3 [==============================] - 0s 13ms/step
# fetching:  RNDR-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  FRR-USDT
# 3/3 [==============================] - 0s 18ms/step
# fetching:  DMTR-USDT
# 3/3 [==============================] - 0s 20ms/step
# fetching:  TRIBE-USDT
# 3/3 [==============================] - 0s 15ms/step
# fetching:  MLK-USDT
# 3/3 [==============================] - 0s 16ms/step

# %%
df_buys
# Out:
#      Close         Volume    Trend  Predicted     Product    Move  Percent  \
# 74 0.49700    37668.52830 -0.00833    0.49926    KNC-USDT 0.00226  0.45569
# 74 0.00299  7677510.27870 -0.00003    0.00299   MITX-USDT 0.00000  0.09413
# 74 0.02123  4833296.03470 -0.00010    0.02135  FLAME-USDT 0.00012  0.56480
# 74 0.07389     3067.35990 -0.00025    0.07394    YLD-USDT 0.00005  0.07379
# 74 0.21500    88328.44870 -0.00347    0.21601    CWS-USDT 0.00101  0.46893
# ..     ...            ...      ...        ...         ...     ...      ...
# 74 0.00064 51289677.06530 -0.00002    0.00064   LITH-USDT 0.00000  0.44233
# 74 0.00144 21456305.58800 -0.00003    0.00146   2CRZ-USDT 0.00002  1.46680
# 74 0.43050   292097.89010 -0.00486    0.43101   RNDR-USDT 0.00051  0.11886
# 74 0.00277 47953811.11690 -0.00005    0.00279   DMTR-USDT 0.00002  0.88802
# 74 0.20342    77635.74710 -0.00377    0.20488    MLK-USDT 0.00146  0.71865
#
#     RawPercent  250Fees   5kFees  10kFees  250Profit  5kProfit  10k0Profit
# 74     0.00456  2.00000 40.00000 50.00000   -0.86078 -17.21551    -4.43101
# 74     0.00094  2.00000 40.00000 50.00000   -1.76467 -35.29341   -40.58683
# 74     0.00565  2.00000 40.00000 50.00000   -0.58801 -11.76024     6.47953
# 74     0.00074  2.00000 40.00000 50.00000   -1.81551 -36.31029   -42.62057
# 74     0.00469  2.00000 40.00000 50.00000   -0.82768 -16.55368    -3.10735
# ..         ...      ...      ...      ...        ...       ...         ...
# 74     0.00442  2.00000 40.00000 50.00000   -0.89418 -17.88366    -5.76732
# 74     0.01467  2.00000 40.00000 50.00000    1.66701  33.34016    96.68031
# 74     0.00119  2.00000 40.00000 50.00000   -1.70286 -34.05723   -38.11445
# 74     0.00888  2.00000 40.00000 50.00000    0.22006   4.40112    38.80225
# 74     0.00719  2.00000 40.00000 50.00000   -0.20336  -4.06727    21.86546
#
# [251 rows x 14 columns]

# %%
df_trade = predict_trade("REN-USD", 90)
df_trade
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-7a43c3c8b26c> in <module>
# ----> 1 df_trade = predict_trade("REN-USD", 90)
#       2 df_trade
#
# <ipython-input-3-fbbc8feb9f73> in predict_trade(product, bars)
#     194
#     195 def predict_trade(product, bars):
# --> 196   [df_full, df_features, npa_scaled, df_raw] = get_coin_data_frames(bars, product)
#     197   predicted = model.predict(npa_scaled).flatten()
#     198
#
# <ipython-input-3-fbbc8feb9f73> in get_coin_data_frames(time, product, granularity)
#     128     df_raw = coinbase_json_to_df(time, product, granularity)
#     129   else:
# --> 130     df_raw = ku_coin_json_to_df(time, product, granularity)
#     131
#     132   df_btc_history = df_raw
#
# <ipython-input-3-fbbc8feb9f73> in ku_coin_json_to_df(delta, product, granularity)
#      98   response_data = js.loads(response_text);
#      99   if (response_data["code"] != "200000"):
# --> 100     raise Exception("Illegal response: " + response_text)
#     101
#     102   df_history = pd.DataFrame(response_data["data"])
#
# Exception: Illegal response: {"code":"400100","msg":"This pair is not provided at present."}

# %%
with open(data_path, 'w', encoding = 'utf-8-sig') as f:
  df_trades.to_csv(f)

# %%
model.save(model_path)

# %%
df_shorts[df_shorts["Product"] == "MPL-USD"]
